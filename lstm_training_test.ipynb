# %% [markdown]
# # Drive

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
#!unzip "/content/drive/MyDrive/UFRPE/6º Período/Redes Neurais/Projeto/projeto_redes_neurais.zip" -d /content/
# !unzip "/content/drive/MyDrive/RN/projeto_redes_neurais.zip" -d /content/
# Out:
# A saída de streaming foi truncada nas últimas 5000 linhas.
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/jieba/include/limonp/BoundedQueue.hpp
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/jieba/include/limonp/ArgvContext.hpp
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/jieba/include/limonp/ForcePublic.hpp
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/jieba/include/limonp/Condition.hpp
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/jieba/include/limonp/Closure.hpp
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/jieba/include/limonp/BlockingQueue.hpp
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/jieba/include/limonp/Thread.hpp
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/jieba/include/limonp/Config.hpp
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/jieba/include/limonp/LocalVector.hpp
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/jieba/include/limonp/BoundedBlockingQueue.hpp
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/jieba/include/limonp/NonCopyable.hpp
#    creating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/config.guess
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/Makefile.am
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/CMakeLists.txt
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/README.md
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/_import_release.sh
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/config.h.in
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/BUILD.bazel
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/ltmain.sh
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/.editorconfig
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/_package_release.cmd
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/.gitignore
#    creating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/m4/
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/m4/ltoptions.m4
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/m4/ac_python_devel.m4
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/m4/lt~obsolete.m4
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/m4/ltsugar.m4
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/m4/ltversion.m4
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/m4/libtool.m4
#    creating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/
#    creating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/script/
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/script/topsort.cc
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/script/weight-class.cc
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/script/reverse.cc
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/script/synchronize.cc
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/script/stateiterator-class.cc
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/script/arciterator-class.cc
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/script/Makefile.am
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/script/compose.cc
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/script/text-io.cc
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/script/CMakeLists.txt
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/script/push.cc
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/script/minimize.cc
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/script/encode.cc
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/script/equal.cc
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/script/prune.cc
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/script/info-impl.cc
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/script/isomorphic.cc
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/script/relabel.cc
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/script/draw.cc
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/script/libfstscript.vcxproj.filters
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/script/epsnormalize.cc
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/script/project.cc
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/script/union.cc
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/script/randequivalent.cc
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/script/convert.cc
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/script/decode.cc
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/script/replace.cc
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/script/closure.cc
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/script/intersect.cc
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/script/invert.cc
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/script/difference.cc
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/script/connect.cc
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/script/concat.cc
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/script/map.cc
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/script/encodemapper-class.cc
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/script/arcsort.cc
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/script/randgen.cc
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/script/shortest-path.cc
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/script/shortest-distance.cc
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/script/Makefile.in
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/script/getters.cc
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/script/determinize.cc
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/script/compile.cc
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/script/libfstscript.vcxproj
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/script/disambiguate.cc
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/script/fst-class.cc
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/script/verify.cc
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/script/reweight.cc
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/script/equivalent.cc
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/script/print.cc
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/script/rmepsilon.cc
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/script/info.cc
#  extracting: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/Makefile.am
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/CMakeLists.txt
#    creating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/include/
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/include/Makefile.am
#    creating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/include/fst/
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/include/fst/state-map.h
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/include/fst/factor-weight.h
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/include/fst/heap.h
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/include/fst/sparse-power-weight.h
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/include/fst/matcher.h
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/include/fst/arc-arena.h
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/include/fst/state-reachable.h
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/include/fst/disambiguate.h
#    creating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/include/fst/script/
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/include/fst/script/disambiguate.h
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/include/fst/script/print.h
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/include/fst/script/fst-class.h
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/include/fst/script/intersect.h
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/include/fst/script/map.h
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/include/fst/script/invert.h
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/include/fst/script/print-impl.h
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/include/fst/script/project.h
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/include/fst/script/reverse.h
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/include/fst/script/text-io.h
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/include/fst/script/stateiterator-class.h
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/include/fst/script/encodemapper-class.h
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/include/fst/script/rmepsilon.h
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/include/fst/script/compose.h
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/include/fst/script/connect.h
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/include/fst/script/register.h
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/include/fst/script/decode.h
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/include/fst/script/arc-class.h
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/include/fst/script/info-impl.h
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/include/fst/script/reweight.h
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/include/fst/script/synchronize.h
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/include/fst/script/randequivalent.h
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/include/fst/script/encode.h
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/include/fst/script/epsnormalize.h
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/include/fst/script/equivalent.h
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/include/fst/script/shortest-distance.h
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/include/fst/script/concat.h
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/include/fst/script/push.h
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/include/fst/script/topsort.h
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/include/fst/script/prune.h
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/include/fst/script/minimize.h
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/include/fst/script/weight-class.h
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/include/fst/script/compile.h
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/include/fst/script/arciterator-class.h
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/include/fst/script/draw.h
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/include/fst/script/union.h
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/include/fst/script/shortest-path.h
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/include/fst/script/relabel.h
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/include/fst/script/fstscript.h
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/include/fst/script/closure.h
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/include/fst/script/compile-impl.h
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/include/fst/script/draw-impl.h
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/include/fst/script/arcsort.h
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/include/fst/script/info.h
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/include/fst/script/fstscript-decl.h
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/include/fst/script/convert.h
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/include/fst/script/determinize.h
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/include/fst/script/verify.h
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/include/fst/script/arg-packs.h
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/include/fst/script/getters.h
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/include/fst/script/equal.h
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/include/fst/script/difference.h
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/include/fst/script/script-impl.h
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/include/fst/script/randgen.h
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/include/fst/script/isomorphic.h
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/include/fst/script/replace.h
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/include/fst/dfs-visit.h
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/include/fst/signed-log-weight.h
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/include/fst/arcfilter.h
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/include/fst/intersect.h
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/include/fst/cache.h
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/include/fst/complement.h
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/include/fst/weight.h
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/include/fst/map.h
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/include/fst/union-find.h
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/include/fst/invert.h
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/include/fst/types.h
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/include/fst/state-table.h
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/include/fst/project.h
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/include/fst/string.h
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/include/fst/product-weight.h
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/include/fst/memory.h
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/include/fst/label-reachable.h
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/include/fst/reverse.h
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/include/fst/union-weight.h
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/include/fst/compact-fst.h
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/include/fst/compose-filter.h
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/include/fst/expanded-fst.h
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/include/fst/string-weight.h
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/include/fst/rmepsilon.h
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/include/fst/compose.h
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/include/fst/connect.h
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/include/fst/lock.h
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/include/fst/test-properties.h
#    creating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/include/fst/test/
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/include/fst/test/fst_test.h
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/include/fst/test/algo_test.h
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/include/fst/test/rand-fst.h
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/include/fst/test/weight-tester.h
#    creating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/include/fst/extensions/
#    creating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/include/fst/extensions/far/
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/include/fst/extensions/far/sttable.h
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/include/fst/extensions/far/farlib.h
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/include/fst/extensions/far/stlist.h
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/include/fst/extensions/far/far-class.h
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/include/fst/extensions/far/print-strings.h
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/include/fst/extensions/far/far.h
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/include/fst/extensions/far/compile-strings.h
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/include/fst/extensions/far/create.h
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/include/fst/extensions/far/info.h
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/include/fst/extensions/far/farscript.h
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/include/fst/extensions/far/getters.h
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/include/fst/extensions/far/equal.h
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/include/fst/extensions/far/extract.h
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/include/fst/extensions/far/script-impl.h
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/include/fst/extensions/far/isomorphic.h
#    creating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/include/fst/extensions/pdt/
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/include/fst/extensions/pdt/expand.h
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/include/fst/extensions/pdt/pdt.h
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/include/fst/extensions/pdt/pdtlib.h
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/include/fst/extensions/pdt/collection.h
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/include/fst/extensions/pdt/reverse.h
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/include/fst/extensions/pdt/paren.h
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/include/fst/extensions/pdt/compose.h
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/include/fst/extensions/pdt/pdtscript.h
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/include/fst/extensions/pdt/shortest-path.h
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/include/fst/extensions/pdt/info.h
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/include/fst/extensions/pdt/getters.h
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/include/fst/extensions/pdt/replace.h
#    creating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/include/fst/extensions/mpdt/
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/include/fst/extensions/mpdt/expand.h
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/include/fst/extensions/mpdt/reverse.h
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/include/fst/extensions/mpdt/compose.h
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/include/fst/extensions/mpdt/read_write_utils.h
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/include/fst/extensions/mpdt/mpdtscript.h
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/include/fst/extensions/mpdt/mpdtlib.h
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/include/fst/extensions/mpdt/info.h
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/include/fst/extensions/mpdt/mpdt.h
#    creating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/include/fst/extensions/linear/
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/include/fst/extensions/linear/linear-fst.h
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/include/fst/extensions/linear/linear-fst-data.h
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/include/fst/extensions/linear/linear-fst-data-builder.h
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/include/fst/extensions/linear/trie.h
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/include/fst/extensions/linear/loglinear-apply.h
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/include/fst/extensions/linear/linearscript.h
#    creating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/include/fst/extensions/compress/
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/include/fst/extensions/compress/randmod.h
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/include/fst/extensions/compress/elias.h
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/include/fst/extensions/compress/compress.h
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/include/fst/extensions/compress/gzfile.h
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/include/fst/extensions/compress/compress-script.h
#    creating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/include/fst/extensions/ngram/
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/include/fst/extensions/ngram/ngram-fst.h
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/include/fst/extensions/ngram/nthbit.h
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/include/fst/extensions/ngram/bitmap-index.h
#    creating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/include/fst/extensions/special/
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/include/fst/extensions/special/rho-fst.h
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/include/fst/extensions/special/sigma-fst.h
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/include/fst/extensions/special/phi-fst.h
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/include/fst/register.h
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/include/fst/compat.h
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/include/fst/sparse-tuple-weight.h
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/include/fst/config.h.in
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/include/fst/reweight.h
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/include/fst/statesort.h
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/include/fst/synchronize.h
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/include/fst/util.h
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/include/fst/lexicographic-weight.h
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/include/fst/symbol-table.h
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/include/fst/randequivalent.h
#  extracting: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/include/fst/config.h
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/include/fst/fst.h
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/include/fst/interval-set.h
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/include/fst/encode.h
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/include/fst/visit.h
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/include/fst/matcher-fst.h
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/include/fst/epsnormalize.h
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/include/fst/accumulator.h
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/include/fst/equivalent.h
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/include/fst/mutable-fst.h
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/include/fst/shortest-distance.h
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/include/fst/const-fst.h
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/include/fst/rmfinalepsilon.h
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/include/fst/concat.h
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/include/fst/push.h
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/include/fst/topsort.h
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/include/fst/prune.h
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/include/fst/edit-fst.h
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/include/fst/minimize.h
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/include/fst/flags.h
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/include/fst/fstlib.h
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/include/fst/union.h
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/include/fst/rational.h
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/include/fst/arc.h
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/include/fst/shortest-path.h
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/include/fst/relabel.h
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/include/fst/closure.h
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/include/fst/float-weight.h
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/include/fst/log.h
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/include/fst/replace-util.h
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/include/fst/vector-fst.h
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/include/fst/filter-state.h
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/include/fst/icu.h
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/include/fst/properties.h
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/include/fst/mapped-file.h
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/include/fst/lookahead-filter.h
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/include/fst/expectation-weight.h
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/include/fst/queue.h
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/include/fst/arcsort.h
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/include/fst/arc-map.h
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/include/fst/lookahead-matcher.h
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/include/fst/bi-table.h
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/include/fst/power-weight.h
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/include/fst/determinize.h
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/include/fst/verify.h
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/include/fst/equal.h
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/include/fst/set-weight.h
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/include/fst/symbol-table-ops.h
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/include/fst/tuple-weight.h
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/include/fst/difference.h
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/include/fst/partition.h
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/include/fst/pair-weight.h
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/include/fst/randgen.h
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/include/fst/generic-register.h
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/include/fst/fst-decl.h
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/include/fst/isomorphic.h
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/include/fst/replace.h
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/include/fst/add-on.h
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/include/Makefile.in
#    creating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/test/
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/test/Makefile.am
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/test/CMakeLists.txt
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/test/weight_test.cc
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/test/algo_test.cc
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/test/fst_test.cc
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/test/Makefile.in
#    creating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/extensions/
#    creating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/extensions/far/
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/extensions/far/far-class.cc
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/extensions/far/stlist.cc
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/extensions/far/farprintstrings.cc
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/extensions/far/Makefile.am
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/extensions/far/strings.cc
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/extensions/far/CMakeLists.txt
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/extensions/far/sttable.cc
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/extensions/far/farisomorphic.cc
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/extensions/far/farcompilestrings.cc
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/extensions/far/farscript.cc
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/extensions/far/farcreate.cc
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/extensions/far/farinfo.cc
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/extensions/far/Makefile.in
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/extensions/far/farextract.cc
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/extensions/far/getters.cc
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/extensions/far/script-impl.cc
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/extensions/far/farequal.cc
#    creating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/extensions/pdt/
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/extensions/pdt/pdtinfo.cc
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/extensions/pdt/Makefile.am
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/extensions/pdt/CMakeLists.txt
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/extensions/pdt/pdtreverse.cc
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/extensions/pdt/pdtcompose.cc
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/extensions/pdt/pdtexpand.cc
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/extensions/pdt/pdtscript.cc
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/extensions/pdt/Makefile.in
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/extensions/pdt/pdtshortestpath.cc
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/extensions/pdt/getters.cc
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/extensions/pdt/pdtreplace.cc
#    creating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/extensions/mpdt/
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/extensions/mpdt/Makefile.am
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/extensions/mpdt/mpdtinfo.cc
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/extensions/mpdt/CMakeLists.txt
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/extensions/mpdt/mpdtcompose.cc
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/extensions/mpdt/mpdtexpand.cc
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/extensions/mpdt/mpdtreverse.cc
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/extensions/mpdt/mpdtscript.cc
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/extensions/mpdt/Makefile.in
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/extensions/Makefile.am
#    creating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/extensions/linear/
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/extensions/linear/Makefile.am
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/extensions/linear/CMakeLists.txt
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/extensions/linear/linear-tagger-fst.cc
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/extensions/linear/fstloglinearapply.cc
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/extensions/linear/linearscript.cc
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/extensions/linear/Makefile.in
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/extensions/linear/linear-classifier-fst.cc
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/extensions/linear/fstlinear.cc
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/extensions/CMakeLists.txt
#    creating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/extensions/lookahead/
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/extensions/lookahead/Makefile.am
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/extensions/lookahead/CMakeLists.txt
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/extensions/lookahead/ilabel_lookahead-fst.cc
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/extensions/lookahead/arc_lookahead-fst.cc
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/extensions/lookahead/olabel_lookahead-fst.cc
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/extensions/lookahead/Makefile.in
#    creating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/extensions/compact/
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/extensions/compact/compact64_unweighted_acceptor-fst.cc
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/extensions/compact/compact64_string-fst.cc
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/extensions/compact/compact64_weighted_string-fst.cc
#   inflating: /content/projeto_redes_neurais/FunASR/runtime/onnxruntime/third_party/openfst/src/extensions/compact/Makefile.am
# ...
#   inflating: /content/projeto_redes_neurais/FunASR/examples/aishell/conformer/utils/text_tokenize.sh
#   inflating: /content/projeto_redes_neurais/FunASR/examples/aishell/conformer/README.md
#    creating: /content/projeto_redes_neurais/FunASR/examples/aishell/conformer/conf/
#   inflating: /content/projeto_redes_neurais/FunASR/examples/aishell/conformer/conf/conformer_rwkv.yaml
#   inflating: /content/projeto_redes_neurais/FunASR/examples/aishell/conformer/conf/conformer_12e_6d_2048_256.yaml
#    creating: /content/projeto_redes_neurais/FunASR/examples/aishell/conformer/local/
#   inflating: /content/projeto_redes_neurais/FunASR/examples/aishell/conformer/local/download_and_untar.sh
#   inflating: /content/projeto_redes_neurais/FunASR/examples/aishell/conformer/local/aishell_data_prep.sh
#   inflating: /content/projeto_redes_neurais/FunASR/examples/aishell/conformer/demo_train_or_finetune.sh
#   inflating: /content/projeto_redes_neurais/FunASR/examples/aishell/conformer/demo_infer.sh
#   inflating: /content/projeto_redes_neurais/FunASR/examples/aishell/conformer/run.sh
#    creating: /content/projeto_redes_neurais/FunASR/examples/aishell/transformer/
#    creating: /content/projeto_redes_neurais/FunASR/examples/aishell/transformer/utils/
#   inflating: /content/projeto_redes_neurais/FunASR/examples/aishell/transformer/utils/split_scp.pl
#   inflating: /content/projeto_redes_neurais/FunASR/examples/aishell/transformer/utils/parse_options.sh
#   inflating: /content/projeto_redes_neurais/FunASR/examples/aishell/transformer/utils/textnorm_zh.py
#   inflating: /content/projeto_redes_neurais/FunASR/examples/aishell/transformer/utils/fix_data_feat.sh
#   inflating: /content/projeto_redes_neurais/FunASR/examples/aishell/transformer/utils/text_tokenize.py
#   inflating: /content/projeto_redes_neurais/FunASR/examples/aishell/transformer/utils/filter_scp.pl
#   inflating: /content/projeto_redes_neurais/FunASR/examples/aishell/transformer/utils/shuffle_list.pl
#   inflating: /content/projeto_redes_neurais/FunASR/examples/aishell/transformer/utils/extract_embeds.py
#   inflating: /content/projeto_redes_neurais/FunASR/examples/aishell/transformer/utils/text2token.py
#   inflating: /content/projeto_redes_neurais/FunASR/examples/aishell/transformer/utils/compute_wer.py
#   inflating: /content/projeto_redes_neurais/FunASR/examples/aishell/transformer/utils/postprocess_text_zh.py
#   inflating: /content/projeto_redes_neurais/FunASR/examples/aishell/transformer/utils/fix_data.sh
#   inflating: /content/projeto_redes_neurais/FunASR/examples/aishell/transformer/utils/text_tokenize.sh
#   inflating: /content/projeto_redes_neurais/FunASR/examples/aishell/transformer/README.md
#    creating: /content/projeto_redes_neurais/FunASR/examples/aishell/transformer/conf/
#   inflating: /content/projeto_redes_neurais/FunASR/examples/aishell/transformer/conf/transformer_12e_6d_2048_256.yaml
#    creating: /content/projeto_redes_neurais/FunASR/examples/aishell/transformer/local/
#   inflating: /content/projeto_redes_neurais/FunASR/examples/aishell/transformer/local/download_and_untar.sh
#   inflating: /content/projeto_redes_neurais/FunASR/examples/aishell/transformer/local/aishell_data_prep.sh
#   inflating: /content/projeto_redes_neurais/FunASR/examples/aishell/transformer/demo_train_or_finetune.sh
#   inflating: /content/projeto_redes_neurais/FunASR/examples/aishell/transformer/demo_infer.sh
#   inflating: /content/projeto_redes_neurais/FunASR/examples/aishell/transformer/run.sh
#    creating: /content/projeto_redes_neurais/FunASR/examples/aishell/branchformer/
#    creating: /content/projeto_redes_neurais/FunASR/examples/aishell/branchformer/utils/
#   inflating: /content/projeto_redes_neurais/FunASR/examples/aishell/branchformer/utils/split_scp.pl
#   inflating: /content/projeto_redes_neurais/FunASR/examples/aishell/branchformer/utils/parse_options.sh
#   inflating: /content/projeto_redes_neurais/FunASR/examples/aishell/branchformer/utils/textnorm_zh.py
#   inflating: /content/projeto_redes_neurais/FunASR/examples/aishell/branchformer/utils/fix_data_feat.sh
#   inflating: /content/projeto_redes_neurais/FunASR/examples/aishell/branchformer/utils/text_tokenize.py
#   inflating: /content/projeto_redes_neurais/FunASR/examples/aishell/branchformer/utils/filter_scp.pl
#   inflating: /content/projeto_redes_neurais/FunASR/examples/aishell/branchformer/utils/shuffle_list.pl
#   inflating: /content/projeto_redes_neurais/FunASR/examples/aishell/branchformer/utils/extract_embeds.py
#   inflating: /content/projeto_redes_neurais/FunASR/examples/aishell/branchformer/utils/text2token.py
#   inflating: /content/projeto_redes_neurais/FunASR/examples/aishell/branchformer/utils/compute_wer.py
#   inflating: /content/projeto_redes_neurais/FunASR/examples/aishell/branchformer/utils/postprocess_text_zh.py
#   inflating: /content/projeto_redes_neurais/FunASR/examples/aishell/branchformer/utils/fix_data.sh
#   inflating: /content/projeto_redes_neurais/FunASR/examples/aishell/branchformer/utils/text_tokenize.sh
#   inflating: /content/projeto_redes_neurais/FunASR/examples/aishell/branchformer/README.md
#    creating: /content/projeto_redes_neurais/FunASR/examples/aishell/branchformer/conf/
#   inflating: /content/projeto_redes_neurais/FunASR/examples/aishell/branchformer/conf/branchformer_12e_6d_2048_256.yaml
#    creating: /content/projeto_redes_neurais/FunASR/examples/aishell/branchformer/local/
#   inflating: /content/projeto_redes_neurais/FunASR/examples/aishell/branchformer/local/download_and_untar.sh
#   inflating: /content/projeto_redes_neurais/FunASR/examples/aishell/branchformer/local/aishell_data_prep.sh
#   inflating: /content/projeto_redes_neurais/FunASR/examples/aishell/branchformer/demo_train_or_finetune.sh
#   inflating: /content/projeto_redes_neurais/FunASR/examples/aishell/branchformer/demo_infer.sh
#   inflating: /content/projeto_redes_neurais/FunASR/examples/aishell/branchformer/run.sh
#   inflating: /content/projeto_redes_neurais/FunASR/examples/aishell/branchformer/infer.sh
#    creating: /content/projeto_redes_neurais/FunASR/examples/aishell/paraformer/
#    creating: /content/projeto_redes_neurais/FunASR/examples/aishell/paraformer/utils/
#   inflating: /content/projeto_redes_neurais/FunASR/examples/aishell/paraformer/utils/split_scp.pl
#   inflating: /content/projeto_redes_neurais/FunASR/examples/aishell/paraformer/utils/parse_options.sh
#   inflating: /content/projeto_redes_neurais/FunASR/examples/aishell/paraformer/utils/textnorm_zh.py
#   inflating: /content/projeto_redes_neurais/FunASR/examples/aishell/paraformer/utils/fix_data_feat.sh
#   inflating: /content/projeto_redes_neurais/FunASR/examples/aishell/paraformer/utils/text_tokenize.py
#   inflating: /content/projeto_redes_neurais/FunASR/examples/aishell/paraformer/utils/filter_scp.pl
#   inflating: /content/projeto_redes_neurais/FunASR/examples/aishell/paraformer/utils/shuffle_list.pl
#   inflating: /content/projeto_redes_neurais/FunASR/examples/aishell/paraformer/utils/extract_embeds.py
#   inflating: /content/projeto_redes_neurais/FunASR/examples/aishell/paraformer/utils/text2token.py
#   inflating: /content/projeto_redes_neurais/FunASR/examples/aishell/paraformer/utils/compute_wer.py
#   inflating: /content/projeto_redes_neurais/FunASR/examples/aishell/paraformer/utils/postprocess_text_zh.py
#   inflating: /content/projeto_redes_neurais/FunASR/examples/aishell/paraformer/utils/fix_data.sh
#   inflating: /content/projeto_redes_neurais/FunASR/examples/aishell/paraformer/utils/text_tokenize.sh
#   inflating: /content/projeto_redes_neurais/FunASR/examples/aishell/paraformer/README.md
#    creating: /content/projeto_redes_neurais/FunASR/examples/aishell/paraformer/conf/
#   inflating: /content/projeto_redes_neurais/FunASR/examples/aishell/paraformer/conf/paraformer_conformer_12e_6d_2048_256.yaml
#    creating: /content/projeto_redes_neurais/FunASR/examples/aishell/paraformer/local/
#   inflating: /content/projeto_redes_neurais/FunASR/examples/aishell/paraformer/local/download_and_untar.sh
#   inflating: /content/projeto_redes_neurais/FunASR/examples/aishell/paraformer/local/aishell_data_prep.sh
#   inflating: /content/projeto_redes_neurais/FunASR/examples/aishell/paraformer/demo_train_or_finetune.sh
#   inflating: /content/projeto_redes_neurais/FunASR/examples/aishell/paraformer/demo_infer.sh
#   inflating: /content/projeto_redes_neurais/FunASR/examples/aishell/paraformer/run.sh
#    creating: /content/projeto_redes_neurais/FunASR/examples/aishell/e_branchformer/
#    creating: /content/projeto_redes_neurais/FunASR/examples/aishell/e_branchformer/utils/
#   inflating: /content/projeto_redes_neurais/FunASR/examples/aishell/e_branchformer/utils/split_scp.pl
#   inflating: /content/projeto_redes_neurais/FunASR/examples/aishell/e_branchformer/utils/parse_options.sh
#   inflating: /content/projeto_redes_neurais/FunASR/examples/aishell/e_branchformer/utils/textnorm_zh.py
#   inflating: /content/projeto_redes_neurais/FunASR/examples/aishell/e_branchformer/utils/fix_data_feat.sh
#   inflating: /content/projeto_redes_neurais/FunASR/examples/aishell/e_branchformer/utils/text_tokenize.py
#   inflating: /content/projeto_redes_neurais/FunASR/examples/aishell/e_branchformer/utils/filter_scp.pl
#   inflating: /content/projeto_redes_neurais/FunASR/examples/aishell/e_branchformer/utils/shuffle_list.pl
#   inflating: /content/projeto_redes_neurais/FunASR/examples/aishell/e_branchformer/utils/extract_embeds.py
#   inflating: /content/projeto_redes_neurais/FunASR/examples/aishell/e_branchformer/utils/text2token.py
#   inflating: /content/projeto_redes_neurais/FunASR/examples/aishell/e_branchformer/utils/compute_wer.py
#   inflating: /content/projeto_redes_neurais/FunASR/examples/aishell/e_branchformer/utils/postprocess_text_zh.py
#   inflating: /content/projeto_redes_neurais/FunASR/examples/aishell/e_branchformer/utils/fix_data.sh
#   inflating: /content/projeto_redes_neurais/FunASR/examples/aishell/e_branchformer/utils/text_tokenize.sh
#   inflating: /content/projeto_redes_neurais/FunASR/examples/aishell/e_branchformer/README.md
#    creating: /content/projeto_redes_neurais/FunASR/examples/aishell/e_branchformer/conf/
#   inflating: /content/projeto_redes_neurais/FunASR/examples/aishell/e_branchformer/conf/e_branchformer_12e_6d_2048_256.yaml
#    creating: /content/projeto_redes_neurais/FunASR/examples/aishell/e_branchformer/local/
#   inflating: /content/projeto_redes_neurais/FunASR/examples/aishell/e_branchformer/local/download_and_untar.sh
#   inflating: /content/projeto_redes_neurais/FunASR/examples/aishell/e_branchformer/local/aishell_data_prep.sh
#   inflating: /content/projeto_redes_neurais/FunASR/examples/aishell/e_branchformer/demo_train_or_finetune.sh
#   inflating: /content/projeto_redes_neurais/FunASR/examples/aishell/e_branchformer/demo_infer.sh
#   inflating: /content/projeto_redes_neurais/FunASR/examples/aishell/e_branchformer/run.sh
#    creating: /content/projeto_redes_neurais/FunASR/examples/aishell/e_paraformer/
#    creating: /content/projeto_redes_neurais/FunASR/examples/aishell/e_paraformer/utils/
#   inflating: /content/projeto_redes_neurais/FunASR/examples/aishell/e_paraformer/utils/split_scp.pl
#   inflating: /content/projeto_redes_neurais/FunASR/examples/aishell/e_paraformer/utils/parse_options.sh
#   inflating: /content/projeto_redes_neurais/FunASR/examples/aishell/e_paraformer/utils/textnorm_zh.py
#   inflating: /content/projeto_redes_neurais/FunASR/examples/aishell/e_paraformer/utils/fix_data_feat.sh
#   inflating: /content/projeto_redes_neurais/FunASR/examples/aishell/e_paraformer/utils/text_tokenize.py
#   inflating: /content/projeto_redes_neurais/FunASR/examples/aishell/e_paraformer/utils/filter_scp.pl
#   inflating: /content/projeto_redes_neurais/FunASR/examples/aishell/e_paraformer/utils/shuffle_list.pl
#   inflating: /content/projeto_redes_neurais/FunASR/examples/aishell/e_paraformer/utils/extract_embeds.py
#   inflating: /content/projeto_redes_neurais/FunASR/examples/aishell/e_paraformer/utils/text2token.py
#   inflating: /content/projeto_redes_neurais/FunASR/examples/aishell/e_paraformer/utils/compute_wer.py
#   inflating: /content/projeto_redes_neurais/FunASR/examples/aishell/e_paraformer/utils/postprocess_text_zh.py
#   inflating: /content/projeto_redes_neurais/FunASR/examples/aishell/e_paraformer/utils/fix_data.sh
#   inflating: /content/projeto_redes_neurais/FunASR/examples/aishell/e_paraformer/utils/text_tokenize.sh
#    creating: /content/projeto_redes_neurais/FunASR/examples/aishell/e_paraformer/conf/
#   inflating: /content/projeto_redes_neurais/FunASR/examples/aishell/e_paraformer/conf/e_paraformer_conformer_12e_6d_2048_256.yaml
#    creating: /content/projeto_redes_neurais/FunASR/examples/aishell/e_paraformer/local/
#   inflating: /content/projeto_redes_neurais/FunASR/examples/aishell/e_paraformer/local/download_and_untar.sh
#   inflating: /content/projeto_redes_neurais/FunASR/examples/aishell/e_paraformer/local/aishell_data_prep.sh
#   inflating: /content/projeto_redes_neurais/FunASR/examples/aishell/e_paraformer/demo_train_or_finetune.sh
#   inflating: /content/projeto_redes_neurais/FunASR/examples/aishell/e_paraformer/demo_infer.sh
#   inflating: /content/projeto_redes_neurais/FunASR/examples/aishell/e_paraformer/run.sh
#    creating: /content/projeto_redes_neurais/FunASR/examples/wenetspeech/
#    creating: /content/projeto_redes_neurais/FunASR/examples/wenetspeech/conformer/
#    creating: /content/projeto_redes_neurais/FunASR/examples/wenetspeech/conformer/utils/
#   inflating: /content/projeto_redes_neurais/FunASR/examples/wenetspeech/conformer/utils/split_scp.pl
#   inflating: /content/projeto_redes_neurais/FunASR/examples/wenetspeech/conformer/utils/parse_options.sh
#   inflating: /content/projeto_redes_neurais/FunASR/examples/wenetspeech/conformer/utils/textnorm_zh.py
#   inflating: /content/projeto_redes_neurais/FunASR/examples/wenetspeech/conformer/utils/fix_data_feat.sh
#   inflating: /content/projeto_redes_neurais/FunASR/examples/wenetspeech/conformer/utils/text_tokenize.py
#   inflating: /content/projeto_redes_neurais/FunASR/examples/wenetspeech/conformer/utils/filter_scp.pl
#   inflating: /content/projeto_redes_neurais/FunASR/examples/wenetspeech/conformer/utils/shuffle_list.pl
#   inflating: /content/projeto_redes_neurais/FunASR/examples/wenetspeech/conformer/utils/extract_embeds.py
#   inflating: /content/projeto_redes_neurais/FunASR/examples/wenetspeech/conformer/utils/text2token.py
#   inflating: /content/projeto_redes_neurais/FunASR/examples/wenetspeech/conformer/utils/compute_wer.py
#   inflating: /content/projeto_redes_neurais/FunASR/examples/wenetspeech/conformer/utils/postprocess_text_zh.py
#   inflating: /content/projeto_redes_neurais/FunASR/examples/wenetspeech/conformer/utils/fix_data.sh
#   inflating: /content/projeto_redes_neurais/FunASR/examples/wenetspeech/conformer/utils/text_tokenize.sh
#   inflating: /content/projeto_redes_neurais/FunASR/examples/wenetspeech/conformer/README.md
#    creating: /content/projeto_redes_neurais/FunASR/examples/wenetspeech/conformer/conf/
#   inflating: /content/projeto_redes_neurais/FunASR/examples/wenetspeech/conformer/conf/conformer_12e_6d_2048_512.yaml
#    creating: /content/projeto_redes_neurais/FunASR/examples/wenetspeech/conformer/local/
#   inflating: /content/projeto_redes_neurais/FunASR/examples/wenetspeech/conformer/local/download_and_untar.sh
#   inflating: /content/projeto_redes_neurais/FunASR/examples/wenetspeech/conformer/local/aishell_data_prep.sh
#   inflating: /content/projeto_redes_neurais/FunASR/examples/wenetspeech/conformer/run.sh
#   inflating: /content/projeto_redes_neurais/FunASR/examples/README_zh.md
#   inflating: /content/projeto_redes_neurais/FunASR/README_zh.md
#    creating: /content/projeto_redes_neurais/data/
#    creating: /content/projeto_redes_neurais/data/raw/
#    creating: /content/projeto_redes_neurais/data/processed/

# %% [markdown]
# # Imports

# %%
# !pip install -r /content/projeto_redes_neurais/requirements.txt
# !pip install -r /content/requirements.txt
# !pip install jiwer
# Out:
# Requirement already satisfied: torch in /usr/local/lib/python3.11/dist-packages (from -r /content/projeto_redes_neurais/requirements.txt (line 1)) (2.5.1+cu124)
# Requirement already satisfied: torchaudio in /usr/local/lib/python3.11/dist-packages (from -r /content/projeto_redes_neurais/requirements.txt (line 2)) (2.5.1+cu124)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from -r /content/projeto_redes_neurais/requirements.txt (line 3)) (1.26.4)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from -r /content/projeto_redes_neurais/requirements.txt (line 4)) (1.13.1)
# Requirement already satisfied: librosa in /usr/local/lib/python3.11/dist-packages (from -r /content/projeto_redes_neurais/requirements.txt (line 5)) (0.10.2.post1)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from -r /content/projeto_redes_neurais/requirements.txt (line 6)) (4.67.1)
# Collecting tensorboardX (from -r /content/projeto_redes_neurais/requirements.txt (line 7))
#   Downloading tensorboardX-2.6.2.2-py2.py3-none-any.whl.metadata (5.8 kB)
# Collecting hydra-core (from -r /content/projeto_redes_neurais/requirements.txt (line 8))
#   Downloading hydra_core-1.3.2-py3-none-any.whl.metadata (5.5 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch->-r /content/projeto_redes_neurais/requirements.txt (line 1)) (3.17.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.11/dist-packages (from torch->-r /content/projeto_redes_neurais/requirements.txt (line 1)) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch->-r /content/projeto_redes_neurais/requirements.txt (line 1)) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch->-r /content/projeto_redes_neurais/requirements.txt (line 1)) (3.1.5)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch->-r /content/projeto_redes_neurais/requirements.txt (line 1)) (2024.10.0)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch->-r /content/projeto_redes_neurais/requirements.txt (line 1))
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch->-r /content/projeto_redes_neurais/requirements.txt (line 1))
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch->-r /content/projeto_redes_neurais/requirements.txt (line 1))
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch->-r /content/projeto_redes_neurais/requirements.txt (line 1))
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch->-r /content/projeto_redes_neurais/requirements.txt (line 1))
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch->-r /content/projeto_redes_neurais/requirements.txt (line 1))
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch->-r /content/projeto_redes_neurais/requirements.txt (line 1))
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch->-r /content/projeto_redes_neurais/requirements.txt (line 1))
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch->-r /content/projeto_redes_neurais/requirements.txt (line 1))
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch->-r /content/projeto_redes_neurais/requirements.txt (line 1)) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch->-r /content/projeto_redes_neurais/requirements.txt (line 1)) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch->-r /content/projeto_redes_neurais/requirements.txt (line 1))
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.1.0 in /usr/local/lib/python3.11/dist-packages (from torch->-r /content/projeto_redes_neurais/requirements.txt (line 1)) (3.1.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch->-r /content/projeto_redes_neurais/requirements.txt (line 1)) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch->-r /content/projeto_redes_neurais/requirements.txt (line 1)) (1.3.0)
# Requirement already satisfied: audioread>=2.1.9 in /usr/local/lib/python3.11/dist-packages (from librosa->-r /content/projeto_redes_neurais/requirements.txt (line 5)) (3.0.1)
# Requirement already satisfied: scikit-learn>=0.20.0 in /usr/local/lib/python3.11/dist-packages (from librosa->-r /content/projeto_redes_neurais/requirements.txt (line 5)) (1.6.1)
# Requirement already satisfied: joblib>=0.14 in /usr/local/lib/python3.11/dist-packages (from librosa->-r /content/projeto_redes_neurais/requirements.txt (line 5)) (1.4.2)
# Requirement already satisfied: decorator>=4.3.0 in /usr/local/lib/python3.11/dist-packages (from librosa->-r /content/projeto_redes_neurais/requirements.txt (line 5)) (4.4.2)
# Requirement already satisfied: numba>=0.51.0 in /usr/local/lib/python3.11/dist-packages (from librosa->-r /content/projeto_redes_neurais/requirements.txt (line 5)) (0.61.0)
# Requirement already satisfied: soundfile>=0.12.1 in /usr/local/lib/python3.11/dist-packages (from librosa->-r /content/projeto_redes_neurais/requirements.txt (line 5)) (0.13.1)
# Requirement already satisfied: pooch>=1.1 in /usr/local/lib/python3.11/dist-packages (from librosa->-r /content/projeto_redes_neurais/requirements.txt (line 5)) (1.8.2)
# Requirement already satisfied: soxr>=0.3.2 in /usr/local/lib/python3.11/dist-packages (from librosa->-r /content/projeto_redes_neurais/requirements.txt (line 5)) (0.5.0.post1)
# Requirement already satisfied: lazy-loader>=0.1 in /usr/local/lib/python3.11/dist-packages (from librosa->-r /content/projeto_redes_neurais/requirements.txt (line 5)) (0.4)
# Requirement already satisfied: msgpack>=1.0 in /usr/local/lib/python3.11/dist-packages (from librosa->-r /content/projeto_redes_neurais/requirements.txt (line 5)) (1.1.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from tensorboardX->-r /content/projeto_redes_neurais/requirements.txt (line 7)) (24.2)
# Requirement already satisfied: protobuf>=3.20 in /usr/local/lib/python3.11/dist-packages (from tensorboardX->-r /content/projeto_redes_neurais/requirements.txt (line 7)) (4.25.6)
# Collecting omegaconf<2.4,>=2.2 (from hydra-core->-r /content/projeto_redes_neurais/requirements.txt (line 8))
#   Downloading omegaconf-2.3.0-py3-none-any.whl.metadata (3.9 kB)
# Collecting antlr4-python3-runtime==4.9.* (from hydra-core->-r /content/projeto_redes_neurais/requirements.txt (line 8))
#   Downloading antlr4-python3-runtime-4.9.3.tar.gz (117 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.0/117.0 kB 5.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: llvmlite<0.45,>=0.44.0dev0 in /usr/local/lib/python3.11/dist-packages (from numba>=0.51.0->librosa->-r /content/projeto_redes_neurais/requirements.txt (line 5)) (0.44.0)
# Requirement already satisfied: PyYAML>=5.1.0 in /usr/local/lib/python3.11/dist-packages (from omegaconf<2.4,>=2.2->hydra-core->-r /content/projeto_redes_neurais/requirements.txt (line 8)) (6.0.2)
# Requirement already satisfied: platformdirs>=2.5.0 in /usr/local/lib/python3.11/dist-packages (from pooch>=1.1->librosa->-r /content/projeto_redes_neurais/requirements.txt (line 5)) (4.3.6)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.11/dist-packages (from pooch>=1.1->librosa->-r /content/projeto_redes_neurais/requirements.txt (line 5)) (2.32.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn>=0.20.0->librosa->-r /content/projeto_redes_neurais/requirements.txt (line 5)) (3.5.0)
# Requirement already satisfied: cffi>=1.0 in /usr/local/lib/python3.11/dist-packages (from soundfile>=0.12.1->librosa->-r /content/projeto_redes_neurais/requirements.txt (line 5)) (1.17.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch->-r /content/projeto_redes_neurais/requirements.txt (line 1)) (3.0.2)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.11/dist-packages (from cffi>=1.0->soundfile>=0.12.1->librosa->-r /content/projeto_redes_neurais/requirements.txt (line 5)) (2.22)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.19.0->pooch>=1.1->librosa->-r /content/projeto_redes_neurais/requirements.txt (line 5)) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.19.0->pooch>=1.1->librosa->-r /content/projeto_redes_neurais/requirements.txt (line 5)) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.19.0->pooch>=1.1->librosa->-r /content/projeto_redes_neurais/requirements.txt (line 5)) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.19.0->pooch>=1.1->librosa->-r /content/projeto_redes_neurais/requirements.txt (line 5)) (2025.1.31)
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.8 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 66.9 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 35.3 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 59.7 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.8 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.9 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 22.5 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 6.9 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.9 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 85.6 MB/s eta 0:00:00
# Downloading tensorboardX-2.6.2.2-py2.py3-none-any.whl (101 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.7/101.7 kB 9.7 MB/s eta 0:00:00
# Downloading hydra_core-1.3.2-py3-none-any.whl (154 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.5/154.5 kB 14.8 MB/s eta 0:00:00
# Downloading omegaconf-2.3.0-py3-none-any.whl (79 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.5/79.5 kB 7.7 MB/s eta 0:00:00
# Building wheels for collected packages: antlr4-python3-runtime
#   Building wheel for antlr4-python3-runtime (setup.py) ... done
#   Created wheel for antlr4-python3-runtime: filename=antlr4_python3_runtime-4.9.3-py3-none-any.whl size=144555 sha256=48d5a91853ece99a990d0f906a228a077f4b6c5b4c3b4af4784488068f8f256e
#   Stored in directory: /root/.cache/pip/wheels/1a/97/32/461f837398029ad76911109f07047fde1d7b661a147c7c56d1
# Successfully built antlr4-python3-runtime
# Installing collected packages: antlr4-python3-runtime, tensorboardX, omegaconf, nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, hydra-core, nvidia-cusolver-cu12
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
# Successfully installed antlr4-python3-runtime-4.9.3 hydra-core-1.3.2 nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nvjitlink-cu12-12.4.127 omegaconf-2.3.0 tensorboardX-2.6.2.2
# Collecting jiwer
#   Downloading jiwer-3.1.0-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: click>=8.1.8 in /usr/local/lib/python3.11/dist-packages (from jiwer) (8.1.8)
# Collecting rapidfuzz>=3.9.7 (from jiwer)
#   Downloading rapidfuzz-3.12.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (11 kB)
# Downloading jiwer-3.1.0-py3-none-any.whl (22 kB)
# Downloading rapidfuzz-3.12.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 45.0 MB/s eta 0:00:00
# Installing collected packages: rapidfuzz, jiwer
# Successfully installed jiwer-3.1.0 rapidfuzz-3.12.1

# %%
# Bibliotecas padrão
import os
os.environ['TORCHDYNAMO_DISABLE'] = '1'
import sys
import re
import argparse

# Bibliotecas de terceiros
import importlib.metadata
from tqdm import tqdm

# PyTorch e módulos relacionados
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.nn.utils.rnn import pad_sequence
from torch.utils.data import Dataset, Subset, DataLoader, random_split

# Torchaudio e torchvision
import torchvision
import torchaudio
import torchaudio.transforms as transforms

# Avaliação de ASR
import jiwer
import numpy as np

from collections import defaultdict
from jiwer import wer
from torch.serialization import add_safe_globals

# %% [markdown]
# ## Verificar se está usando a GPU

# %%
# Verificar se a GPU está disponível
device = "cuda" if torch.cuda.is_available() else "cpu"
print(f"Usando o dispositivo: {device}")
# Out:
# Usando o dispositivo: cuda

# %% [markdown]
# ## Verificar as dependências

# %%
print("Torch version:", torch.__version__)
print("Torchvision version:", torchvision.__version__)
print("Torchaudio version:", torchaudio.__version__)
print("Jiwer version:", importlib.metadata.version("jiwer"))
# Out:
# Torch version: 2.5.1+cu124
# Torchvision version: 0.20.1+cu124
# Torchaudio version: 2.5.1+cu124
# Jiwer version: 3.1.0

# %% [markdown]
# # Dataset

# %% [markdown]
# ## Pre-processamento da base

# %% [markdown]
# 1. Baixe a base de teste

# %%
# !wget -P /content/projeto_redes_neurais/data/raw https://www.openslr.org/resources/12/test-clean.tar.gz
# Out:
# --2025-02-26 03:13:47--  https://www.openslr.org/resources/12/test-clean.tar.gz
# Resolving www.openslr.org (www.openslr.org)... 46.101.158.64
# Connecting to www.openslr.org (www.openslr.org)|46.101.158.64|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://openslr.elda.org/resources/12/test-clean.tar.gz [following]
# --2025-02-26 03:13:47--  https://openslr.elda.org/resources/12/test-clean.tar.gz
# Resolving openslr.elda.org (openslr.elda.org)... 141.94.109.138, 2001:41d0:203:ad8a::
# Connecting to openslr.elda.org (openslr.elda.org)|141.94.109.138|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length:
flac
# LibriSpeech/test-clean/7127/75946/7127-75946-0028.flac
# LibriSpeech/test-clean/7127/75946/7127-75946-0029.flac
# LibriSpeech/test-clean/2961/
# LibriSpeech/test-clean/2961/960/
# LibriSpeech/test-clean/2961/960/2961-960-0012.flac
# LibriSpeech/test-clean/2961/960/2961-960-0022.flac
# LibriSpeech/test-clean/2961/960/2961-960-0006.flac
# LibriSpeech/test-clean/2961/960/2961-960-0015.flac
# LibriSpeech/test-clean/2961/960/2961-960-0005.flac
# LibriSpeech/test-clean/2961/960/2961-960.trans.txt
# LibriSpeech/test-clean/2961/960/2961-960-0018.flac
# LibriSpeech/test-clean/2961/960/2961-960-0003.flac
# LibriSpeech/test-clean/2961/960/2961-960-0016.flac
# LibriSpeech/test-clean/2961/960/2961-960-0013.flac
# LibriSpeech/test-clean/2961/960/2961-960-0014.flac
# LibriSpeech/test-clean/2961/960/2961-960-0004.flac
# LibriSpeech/test-clean/2961/960/2961-960-0009.flac
# LibriSpeech/test-clean/2961/960/2961-960-0021.flac
# LibriSpeech/test-clean/2961/960/2961-960-0020.flac
# LibriSpeech/test-clean/2961/960/2961-960-0002.flac
# LibriSpeech/test-clean/2961/960/2961-960-0008.flac
# LibriSpeech/test-clean/2961/960/2961-960-0010.flac
# LibriSpeech/test-clean/2961/960/2961-960-0011.flac
# LibriSpeech/test-clean/2961/960/2961-960-0007.flac
# LibriSpeech/test-clean/2961/960/2961-960-0017.flac
# LibriSpeech/test-clean/2961/960/2961-960-0001.flac
# LibriSpeech/test-clean/2961/960/2961-960-0019.flac
# LibriSpeech/test-clean/2961/960/2961-960-0000.flac
# LibriSpeech/test-clean/2961/961/
# LibriSpeech/test-clean/2961/961/2961-961-0017.flac
# LibriSpeech/test-clean/2961/961/2961-961-0013.flac
# LibriSpeech/test-clean/2961/961/2961-961-0014.flac
# LibriSpeech/test-clean/2961/961/2961-961-0020.flac
# LibriSpeech/test-clean/2961/961/2961-961-0007.flac
# LibriSpeech/test-clean/2961/961/2961-961-0019.flac
# LibriSpeech/test-clean/2961/961/2961-961-0009.flac
# LibriSpeech/test-clean/2961/961/2961-961-0006.flac
# LibriSpeech/test-clean/2961/961/2961-961-0008.flac
# LibriSpeech/test-clean/2961/961/2961-961-0003.flac
# LibriSpeech/test-clean/2961/961/2961-961-0012.flac
# LibriSpeech/test-clean/2961/961/2961-961-0021.flac
# LibriSpeech/test-clean/2961/961/2961-961-0011.flac
# LibriSpeech/test-clean/2961/961/2961-961-0002.flac
# LibriSpeech/test-clean/2961/961/2961-961-0010.flac
# LibriSpeech/test-clean/2961/961/2961-961-0000.flac
# LibriSpeech/test-clean/2961/961/2961-961.trans.txt
# LibriSpeech/test-clean/2961/961/2961-961-0022.flac
# LibriSpeech/test-clean/2961/961/2961-961-0018.flac
# LibriSpeech/test-clean/2961/961/2961-961-0005.flac
# LibriSpeech/test-clean/2961/961/2961-961-0016.flac
# LibriSpeech/test-clean/2961/961/2961-961-0001.flac
# LibriSpeech/test-clean/2961/961/2961-961-0015.flac
# LibriSpeech/test-clean/2961/961/2961-961-0004.flac
# LibriSpeech/test-clean/8463/
# LibriSpeech/test-clean/8463/287645/
# LibriSpeech/test-clean/8463/287645/8463-287645-0008.flac
# LibriSpeech/test-clean/8463/287645/8463-287645-
# LibriSpeech/test-clean/121/127105/121-127105-0013.flac
# LibriSpeech/test-clean/121/127105/121-127105-0021.flac
# LibriSpeech/test-clean/121/127105/121-127105-0004.flac
# LibriSpeech/test-clean/121/127105/121-127105-0028.flac
# LibriSpeech/test-clean/121/127105/121-127105-0008.flac
# LibriSpeech/test-clean/121/127105/121-127105-0027.flac
# LibriSpeech/test-clean/121/127105/121-127105-0016.flac
# LibriSpeech/test-clean/121/127105/121-127105-0009.flac
# LibriSpeech/test-clean/121/127105/121-127105-0015.flac
# LibriSpeech/test-clean/121/127105/121-127105-0031.flac
# LibriSpeech/test-clean/121/127105/121-127105-0011.flac
# LibriSpeech/test-clean/121/127105/121-127105-0036.flac
# LibriSpeech/test-clean/121/127105/121-127105-0006.flac
# LibriSpeech/test-clean/121/127105/121-127105-0035.flac
# LibriSpeech/test-clean/121/127105/121-127105-0010.flac
# LibriSpeech/test-clean/121/127105/121-127105-0032.flac
# LibriSpeech/test-clean/121/127105/121-127105-0000.flac
# LibriSpeech/test-clean/121/127105/121-127105-0012.flac
# LibriSpeech/test-clean/121/127105/121-127105-0029.flac
# LibriSpeech/test-clean/121/127105/121-127105-0007.flac
# LibriSpeech/test-clean/121/127105/121-127105-0025.flac
# LibriSpeech/test-clean/121/123852/
# LibriSpeech/test-clean/121/123852/121-123852-0003.flac
# LibriSpeech/test-clean/121/123852/121-123852-0000.flac
# LibriSpeech/test-clean/121/123852/121-123852-0002.flac
# LibriSpeech/test-clean/121/123852/121-123852.trans.txt
# LibriSpeech/test-clean/121/123852/121-123852-0001.flac
# LibriSpeech/test-clean/121/123852/121-123852-0004.flac

# %%
dataset = torchaudio.datasets.LIBRISPEECH(root="/content/projeto_redes_neurais/data/raw/", url="test-clean", download=False)

print(f"Total de amostras: {len(dataset)}")

# Pegando os valores corretos do primeiro áudio
waveform, sample_rate, utterance, _, _, _ = dataset[0]

print(f"Formato do áudio: {waveform.shape}, Taxa de amostragem: {sample_rate}")
print(f"Transcrição: {utterance}")
# Out:
# Total de amostras: 2620
# Formato do áudio: torch.Size([1, 166960]), Taxa de amostragem: 16000
# Transcrição: HE HOPED THERE WOULD BE STEW FOR DINNER TURNIPS AND CARROTS AND BRUISED POTATOES AND FAT MUTTON PIECES TO BE LADLED OUT IN THICK PEPPERED FLOUR FATTENED SAUCE

# %% [markdown]
# 3. Realize o pré-processamento da base de dados e construa o vocabulário

# %%
DATA_DIR = "/content/projeto_redes_neurais/data/raw"
PROCESSED_DIR = "/content/projeto_redes_neurais/data/processed"
MODEL_DIR = "/content/drive/MyDrive/RN/modelos"
DATASET_DIR = "/content/projeto_redes_neurais/datasets"

class LibriSpeechDataset(Dataset):
    def __init__(self, root_dir):
        self.dataset = torchaudio.datasets.LIBRISPEECH(root=root_dir, url="test-clean", download=True)
        self.transform = torchaudio.transforms.MelSpectrogram(
            sample_rate=16000,
            n_mels=128,
            n_fft=2048,
            hop_length=512,
            normalized=True
        )
        self.vocab = self._build_vocab()  # Método adicionado

    def _build_vocab(self):
        """Constrói o vocabulário a partir das transcrições"""
        counter = defaultdict(int)
        for idx in range(len(self.dataset)):
            _, _, transcript, _, _, _ = self.dataset[idx]
            for char in transcript.lower():
                counter[char] += 1

        # Caracteres especiais
        vocab = {
            '<blank>': 0,  # Para CTC Loss
            '<unk>': 1      # Caracteres desconhecidos
        }

        # Adiciona caracteres ordenados por frequência
        for idx, (char, count) in enumerate(sorted(counter.items(), key=lambda x: x[1], reverse=True)):
            vocab[char] = idx + 2  # +2 para reservar os primeiros índices
        torch.save(vocab, 'vocab.pt')
        torch.save(vocab, '/content/drive/MyDrive/UFRPE/RN/splits/vocab.pt')
        return vocab

    def __len__(self):
        return len(self.dataset)

    def __getitem__(self, idx):
        waveform, sample_rate, transcript, _, _, _ = self.dataset[idx]
        waveform = waveform.squeeze(0)  # Remove dimensão extra (1, samples) -> (samples)
        spectrogram = self.transform(waveform)
        spectrogram = spectrogram.unsqueeze(0)  # Adiciona canal (1, n_mels, time)

        # Convert texto para índices
        transcript_indices = [
            self.vocab.get(char, self.vocab['<unk>'])
            for char in transcript.lower()
        ]

        return spectrogram, torch.tensor(transcript_indices, dtype=torch.long)

# Função de pré-processamento corrigida
def preprocess_data():
    os.makedirs(PROCESSED_DIR, exist_ok=True)

    dataset = LibriSpeechDataset(DATA_DIR)

    # Salvar dados processados
    processed_data = {
        'waveforms': [d[0] for d in dataset],
        'transcripts': [d[1] for d in dataset],
        'vocab': dataset.vocab
    }

    torch.save(
        processed_data,
        os.path.join(PROCESSED_DIR, "librispeech_processed.pt"),
        _use_new_zipfile_serialization=True
    )
    print(f"Pré-processamento concluído! {len(dataset)} amostras salvas.")

if __name__ == "__main__":
    preprocess_data()
# Out:
# Pré-processamento concluído! 2620 amostras salvas.

# %%
# Etapa 1: Permitir explicitamente a classe customizada
add_safe_globals([LibriSpeechDataset])

# %% [markdown]
# ## Carregando Dataset

# %%
# Função collate_fn
# ========== FUNÇÕES ESSENCIAIS ========== #
def collate_fn(batch):
    batch.sort(key=lambda x: x[0].shape[-1], reverse=True)
    waveforms, transcripts = zip(*batch)

    # Padding dos espectrogramas
    max_time = max(w.shape[-1] for w in waveforms)
    waveforms_padded = torch.stack([
        torch.nn.functional.pad(w, (0, max_time - w.shape[-1]))
        for w in waveforms
    ]).squeeze(1).permute(0, 2, 1)  # Resultado: (B, T, F)

    # Processamento dos textos
    transcript_lengths = torch.tensor([len(t) for t in transcripts], dtype=torch.long)
    transcripts_padded = torch.nn.utils.rnn.pad_sequence(transcripts, batch_first=True)

    return waveforms_padded, transcripts_padded, transcript_lengths

# Função para salvar os conjuntos
def save_splits(train_set, val_set, test_set, vocab):
    os.makedirs(DATASET_DIR, exist_ok=True)

    torch.save({
        'train_indices': train_set.indices,  # Correção: Vírgula apenas entre chaves
        'val_indices': val_set.indices,
        'test_indices': test_set.indices,
        'vocab': vocab
    }, os.path.join(DATASET_DIR, "splits.pt"))


# Função para carregar os conjuntos
def load_splits(dataset):
    splits = torch.load(
        os.path.join(DATASET_DIR, "splits.pt"),
        weights_only=True,
        map_location='cpu'
    )

    from torch.utils.data import Subset
    return (
        Subset(dataset, splits['train_indices']),
        Subset(dataset, splits['val_indices']),
        Subset(dataset, splits['test_indices']),
        splits['vocab']
    )

# %% [markdown]
# # Arquiteturas

# %%
# Classe do modelo atualizada
class SpeechLSTM(nn.Module):
    def __init__(self, input_size=128, hidden_size=256, num_layers=3, num_classes=30):
        super().__init__()
        self.lstm = nn.LSTM(
            input_size=input_size,
            hidden_size=hidden_size,
            num_layers=num_layers,
            batch_first=True,
            bidirectional=True
        )
        self.fc = nn.Linear(hidden_size * 2, num_classes)

    def forward(self, x):
        out, _ = self.lstm(x)
        return nn.functional.log_softmax(self.fc(out), dim=-1)

class OptimizedSpeechLSTM(nn.Module):
    def __init__(self, input_size=128, hidden_size=512, num_layers=4,
                 num_classes=30, conv_channels=64, dropout=0.3):
        super().__init__()

        # Camada de convolução para extração de features
        self.conv = nn.Sequential(
            nn.Conv2d(1, conv_channels, kernel_size=3, stride=1, padding=1),
            nn.BatchNorm2d(conv_channels),
            nn.Hardswish(),
            nn.MaxPool2d(2),
            nn.Dropout(dropout/2)
        )

        # Ajuste da dimensão para LSTM
        self.adaptative_pool = nn.AdaptiveAvgPool2d((None, hidden_size//2))

        # LSTM Profunda Bidirecional
        self.lstm = nn.LSTM(
            input_size=hidden_size//2,
            hidden_size=hidden_size,
            num_layers=num_layers,
            batch_first=True,
            bidirectional=True,
            dropout=dropout if num_layers > 1 else 0
        )

        # Camadas de atenção
        self.attention = nn.MultiheadAttention(
            embed_dim=hidden_size*2,
            num_heads=4,
            dropout=dropout
        )

        # Camadas fully connected
        self.fc = nn.Sequential(
            nn.Linear(hidden_size*2, hidden_size),
            nn.LayerNorm(hidden_size),
            nn.ReLU(),
            nn.Dropout(dropout),
            nn.Linear(hidden_size, num_classes)
        )

        # Inicialização de pesos
        self._init_weights()

    def _init_weights(self):
        for name, module in self.named_modules():
            if isinstance(module, nn.Linear):
                nn.init.kaiming_normal_(module.weight)
                if module.bias is not None:
                    nn.init.constant_(module.bias, 0)
            elif isinstance(module, nn.LSTM):
                for name, param in module.named_parameters():
                    if 'weight_ih' in name:
                        nn.init.xavier_normal_(param)
                    elif 'weight_hh' in name:
                        nn.init.orthogonal_(param)
                    elif 'bias' in name:
                        nn.init.constant_(param, 0)

    def forward(self, x):
        # Input shape: (B, T, F)
        x = x.unsqueeze(1)  # Add channel dim

        # Conv Feature Extraction
        x = self.conv(x)  # (B, C, T, F)
        x = self.adaptative_pool(x)

        # Reshape for LSTM
        B, C, T, F = x.size()
        x = x.permute(0, 2, 1, 3).reshape(B, T, -1)  # (B, T, C*F)

        # LSTM Layers
        x, _ = self.lstm(x)

        # Attention
        x = x.permute(1, 0, 2)  # (T, B, F) for attention
        x, _ = self.attention(x, x, x)
        x = x.permute(1, 0, 2)  # (B, T, F)

        # Output Layer
        x = self.fc(x)
        return nn.functional.log_softmax(x, dim=-1)

class HybridCTCLSTM(nn.Module):
    def __init__(self, input_size=128, hidden_size=256, num_layers=2,
                 num_classes=30, dropout=0.3):
        super().__init__()
        # --- CNN para extrair features mantendo a dimensão temporal ---
        # Nossa ideia: tratar a dimensão de frequência como "altura" e a de tempo como "largura".
        # Suponha que a entrada seja (B, T, F) com F = 128.
        # Primeiro, transponha para (B, F, T) e insira um canal.
        # Aplicamos convoluções que reduzem somente a dimensão de frequência.
        self.cnn = nn.Sequential(
            nn.Conv2d(1, 32, kernel_size=(3,3), stride=(1,1), padding=(1,1)),
            nn.BatchNorm2d(32),
            nn.ReLU(),
            nn.Conv2d(32, 32, kernel_size=(3,3), stride=(1,1), padding=(1,1)),
            nn.BatchNorm2d(32),
            nn.ReLU(),
            # Pooling apenas na dimensão de frequência (F), preservando o tempo (T)
            nn.MaxPool2d(kernel_size=(2,1))
        )
        # Após a CNN, a dimensão de frequência é reduzida pela metade: (F//2)
        # E o número de canais é 32. Assim, para cada time-step teremos um vetor de dimensão: 32 * (input_size//2)
        cnn_output_size = 32 * (input_size // 2)
        # Projeção para ajustar à dimensão de entrada do LSTM:
        self.fc_proj = nn.Linear(cnn_output_size, hidden_size)
        self.dropout = nn.Dropout(dropout)
        # --- LSTM bidirecional ---
        self.lstm = nn.LSTM(
            input_size=hidden_size,
            hidden_size=hidden_size,
            num_layers=num_layers,
            batch_first=True,
            bidirectional=True,
            dropout=dropout if num_layers > 1 else 0
        )
        # --- Camada final: gera logits para cada time-step ---
        self.classifier = nn.Linear(hidden_size*2, num_classes)

    def forward(self, x):
        # x: (B, T, F)  -- onde F corresponde à dimensão de frequência (ex.: 128)
        # Transpor para tratar F como "altura" e T como "largura":
        # Primeiro, transpor para (B, F, T)
        x = x.transpose(1, 2)  # (B, F, T)
        # Adicionar dimensão de canal: (B, 1, F, T)
        x = x.unsqueeze(1)
        # Aplicar a CNN: o pooling (kernel=(2,1)) reduz somente a dimensão de F
        x = self.cnn(x)  # (B, 32, F//2, T)
        # Rearranjar para o LSTM: queremos uma sequência de time-steps com features por time-step.
        # Permutamos para (B, T, 32, F//2)
        x = x.permute(0, 3, 1, 2)
        B, T, C, F_new = x.size()
        # Achatar as dimensões dos canais e frequência:
        x = x.reshape(B, T, C * F_new)  # (B, T, 32*(input_size//2))
        # Projetar para o tamanho de entrada do LSTM:
        x = self.fc_proj(x)  # (B, T, hidden_size)
        x = self.dropout(x)
        # LSTM bidirecional:
        x, _ = self.lstm(x)  # (B, T, hidden_size*2)
        # Classificação: gerar logits para cada time-step
        x = self.classifier(x)  # (B, T, num_classes)
        return F.log_softmax(x, dim=-1)

# %% [markdown]
# # Treinamento

# %% [markdown]
# ## Função evaluate para medir o desempenho no conjunto de validação

# %%
def evaluate(model, loader, criterion):
    model.eval()
    total_loss = 0
    with torch.no_grad():
        for inputs, targets, target_lengths in loader:
            inputs = inputs.to(DEVICE)
            outputs = model(inputs)

            # CORREÇÃO APLICADA AQUI:
            input_lengths = torch.full(
                size=(inputs.size(0),),  # Tupla correta
                fill_value=inputs.size(1),
                dtype=torch.long,
                device=DEVICE
            )

            loss = criterion(
                outputs.permute(1, 0, 2),
                targets.to(DEVICE),
                input_lengths,
                target_lengths.to(DEVICE)
            )
            total_loss += loss.item()

    return total_loss / len(loader)

# %% [markdown]
# ## Treinamento do modelo Speech Base da LSTM

# %%
# Definir hiperparâmetros
EPOCHS = 50
BATCH_SIZE = 16
LEARNING_RATE = 0.001
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Função de treinamento
def train(model, train_loader, val_loader, criterion, optimizer, vocab):
    best_loss = float('inf')

    for epoch in range(EPOCHS):
        model.train()
        total_loss = 0

        for inputs, targets, target_lengths in train_loader:
            inputs = inputs.to(DEVICE)
            targets = targets.to(DEVICE)
            target_lengths = target_lengths.to(DEVICE)

            optimizer.zero_grad()
            outputs = model(inputs)

            input_lengths = torch.full(
                size=(inputs.size(0),),
                fill_value=inputs.size(1),
                dtype=torch.long,
                device=DEVICE
            )

            # Ajuste para formato CTC: (T, N, C)
            log_probs = outputs.permute(1, 0, 2)

            loss = criterion(
                log_probs,
                targets,
                input_lengths,
                target_lengths.to(DEVICE)
            )

            loss.backward()
            optimizer.step()
            total_loss += loss.item()

        # Validação
        val_loss = evaluate(model, val_loader, criterion)

        # Salva o melhor modelo
        if val_loss < best_loss:
            best_loss = val_loss
            torch.save({
                'model_state_dict': model.state_dict(),
                'vocab': vocab
            }, os.path.join(MODEL_DIR, "best_model_SpeechLSTM.pth"))

        print(f"Epoch {epoch+1}/{EPOCHS} | Train Loss: {total_loss/len(train_loader):.4f} | Val Loss: {val_loss:.4f}")

# Função principal atualizada
def main():
    # Carregar dados com segurança
    processed_data = torch.load(
        os.path.join(PROCESSED_DIR, "librispeech_processed.pt"),
        weights_only=True,
        map_location='cpu'
    )

    # Reconstruir dataset manualmente
    class TempDataset(Dataset):
      def __init__(self, data):
          self.waveforms = data['waveforms']
          self.transcripts = data['transcripts']
          self.vocab = data['vocab']

      def __len__(self):
          return len(self.waveforms)

      def __getitem__(self, idx):
          waveform = self.waveforms[idx]
          if waveform.dim() == 2:
              waveform = waveform.unsqueeze(0)
          return waveform, self.transcripts[idx]

    full_dataset = TempDataset(processed_data)

    # Divisão e salvamento
    train_size = int(0.7 * len(full_dataset))
    val_size = int(0.15 * len(full_dataset))
    test_size = len(full_dataset) - train_size - val_size

    train_set, val_set, test_set = random_split(
        full_dataset,
        [train_size, val_size, test_size],
        generator=torch.Generator().manual_seed(42)
    )

    # [2] Salvar as divisões primeiro
    save_splits(train_set, val_set, test_set, full_dataset.vocab)

    # [3] Agora carregar as divisões salvas
    train_set, val_set, test_set, vocab = load_splits(full_dataset)

    # Cria DataLoaders
    train_loader = DataLoader(train_set, batch_size=BATCH_SIZE, collate_fn=collate_fn, shuffle=True)
    val_loader = DataLoader(val_set, batch_size=BATCH_SIZE, collate_fn=collate_fn)

    # Inicializa modelo
    model = SpeechLSTM(num_classes=len(vocab)).to(DEVICE)
    criterion = nn.CTCLoss(blank=vocab['<blank>']).to(DEVICE)
    optimizer = optim.Adam(model.parameters(), lr=LEARNING_RATE)

    # Treino
    train(model, train_loader, val_loader, criterion, optimizer, vocab)

if __name__ == "__main__":
    os.environ['TORCHDYNAMO_DISABLE'] = '1'
    main()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-15-9004ed9d3dc0> in <cell line: 0>()
#     114 if __name__ == "__main__":
#     115     os.environ['TORCHDYNAMO_DISABLE'] = '1'
# --> 116     main()
#
# <ipython-input-15-9004ed9d3dc0> in main()
#     110
#     111     # Treino
# --> 112     train(model, train_loader, val_loader, criterion, optimizer, vocab)
#     113
#     114 if __name__ == "__main__":
#
# <ipython-input-15-9004ed9d3dc0> in train(model, train_loader, val_loader, criterion, optimizer, vocab)
#      39             )
#      40
# ---> 41             loss.backward()
#      42             optimizer.step()
#      43             total_loss += loss.item()
#
# /usr/local/lib/python3.11/dist-packages/torch/_tensor.py in backward(self, gradient, retain_graph, create_graph, inputs)
#     579                 inputs=inputs,
#     580             )
# --> 581         torch.autograd.backward(
#     582             self, gradient, retain_graph, create_graph, inputs=inputs
#     583         )
#
# /usr/local/lib/python3.11/dist-packages/torch/autograd/__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     345     # some Python versions print out the first line of a multi-line function
#     346     # calls in the traceback and some print out the last line
# --> 347     _engine_run_backward(
#     348         tensors,
#     349         grad_tensors_,
#
# /usr/local/lib/python3.11/dist-packages/torch/autograd/graph.py in _engine_run_backward(t_outputs, *args, **kwargs)
#     823         unregister_hooks = _register_logging_hooks_on_whole_graph(t_outputs)
#     824     try:
# --> 825         return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     826             t_outputs, *args, **kwargs
#     827         )  # Calls into the C++ engine to run the backward pass
#
# KeyboardInterrupt:

# %% [markdown]
# ## Avalia o modelo de acordo com a métrica WER no conjunto de testes

# %%
# ========== CONFIGURAÇÕES ========== #
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")
BATCH_SIZE = 16
DATA_DIR = "/content/projeto_redes_neurais/data/raw"
PROCESSED_DIR = "/content/projeto_redes_neurais/data/processed"
MODEL_DIR = "/content/drive/MyDrive/RN/modelos"
DATASET_DIR = "/content/projeto_redes_neurais/datasets"
MODEL_PATH = "/content/drive/MyDrive/RN/modelos/best_model_SpeechLSTM.pth"

# ========== FUNÇÕES ESSENCIAIS ========== #
def collate_fn(batch):
    batch.sort(key=lambda x: x[0].shape[-1], reverse=True)
    waveforms, transcripts = zip(*batch)

    # Padding dos espectrogramas
    max_time = max(w.shape[-1] for w in waveforms)
    waveforms_padded = torch.stack([
        torch.nn.functional.pad(w, (0, max_time - w.shape[-1]))
        for w in waveforms
    ]).squeeze(1).permute(0, 2, 1)

    # Processamento dos textos
    transcript_lengths = torch.tensor([len(t) for t in transcripts], dtype=torch.long)
    transcripts_padded = torch.nn.utils.rnn.pad_sequence(transcripts, batch_first=True)

    return waveforms_padded, transcripts_padded, transcript_lengths

# ========== CARREGAMENTO DE DADOS ========== #
# 1. Carregar dados processados
processed_data = torch.load(
    os.path.join(PROCESSED_DIR, "librispeech_processed.pt"),
    map_location='cpu',
    weights_only=True
)

# 2. Dataset de inferência
class InferenceDataset(torch.utils.data.Dataset):
    def __init__(self, data):
        self.waveforms = data['waveforms']
        self.transcripts = data['transcripts']
        self.vocab = data['vocab']

    def __len__(self):
        return len(self.waveforms)

    def __getitem__(self, idx):
        return self.waveforms[idx], self.transcripts[idx]

full_dataset = InferenceDataset(processed_data)

# 3. Carregar splits
splits = torch.load(
    os.path.join(DATASET_DIR, "splits.pt"),
    map_location='cpu',
    weights_only=True
)
test_set = Subset(full_dataset, splits['test_indices'])

# ========== CARREGAMENTO DO MODELO ========== #
# 4. Carregar checkpoint
checkpoint = torch.load(
    MODEL_PATH,
    map_location=DEVICE,
    weights_only=True
)

# Extrair vocabulário do checkpoint
if 'vocab' not in checkpoint:
    raise KeyError("Vocabulário não encontrado no checkpoint")

vocab = checkpoint['vocab']

# ========== FUNÇÕES DE DECODIFICAÇÃO ========== #
def decode_predictions(ctc_output, vocab, blank_index=0):
    _, max_indices = torch.max(ctc_output, dim=2)
    decoded_texts = []

    for batch in max_indices:
        current_text = []
        prev_char = -1

        for char_idx in batch:
            char_idx = char_idx.item()
            if char_idx != prev_char and char_idx != blank_index:
                if char_idx in vocab.values():
                    current_text.append(char_idx)
            prev_char = char_idx

        idx_to_char = {v: k for k, v in vocab.items()}
        decoded = ''.join([idx_to_char.get(idx, '') for idx in current_text])
        decoded_texts.append(decoded)

    return decoded_texts

# ========== CÁLCULO DO WER ========== #
def calculate_test_wer():
    test_loader = DataLoader(
        test_set,
        batch_size=BATCH_SIZE,
        collate_fn=collate_fn
    )

    total_wer = 0
    total_samples = 0

    with torch.no_grad():
        for batch_idx, (inputs, targets, target_lengths) in enumerate(test_loader):
            inputs = inputs.to(DEVICE)
            outputs = model(inputs)

            # Decodificar previsões
            predictions = decode_predictions(outputs, vocab)

            # Processar referências, ignorando tokens "<blank>"
            idx_to_char = {v: k for k, v in vocab.items()}
            references = []
            valid_indices = []

            for i, target in enumerate(targets):
                try:
                    # Converter índices para texto, ignorando tokens "<blank>"
                    text = ''.join([idx_to_char[idx.item()]
                                    for idx in target
                                    if idx.item() in idx_to_char and idx_to_char[idx.item()] != '<blank>'])
                    if not text.strip():
                        raise ValueError("Texto vazio")
                    references.append(text)
                    valid_indices.append(i)
                except Exception as e:
                    print(f"Batch {batch_idx}, Amostra {i} ignorada: {str(e)}")
                    continue

            # Para visualização: imprimir a frase real e a prevista para cada amostra válida
            valid_predictions = [predictions[i] for i in valid_indices]
            for ref, pred in zip(references, valid_predictions):
                print(f"Real: {ref}  |  Previsto: {pred}")

            # Calcular WER para o batch
            if len(references) > 0:
                try:
                    batch_wer = wer(references, valid_predictions)
                    total_wer += batch_wer * len(references)
                    total_samples += len(references)
                except Exception as e:
                    print(f"Erro no batch {batch_idx}: {str(e)}")

    return total_wer / total_samples if total_samples > 0 else float('inf')

# ========== EXECUÇÃO PRINCIPAL ========== #
if __name__ == "__main__":
    # Instanciar modelo
    model = SpeechLSTM(num_classes=len(vocab)).to(DEVICE)

    # Carregar pesos
    try:
        model.load_state_dict(checkpoint['model_state_dict'])
        print("Modelo carregado com sucesso!")
    except Exception as e:
        print(f"Falha ao carregar modelo: {str(e)}")
        raise

    model.eval()

    # Calcular WER
    try:
        test_wer = calculate_test_wer()
        print(f"\n✅ Resultado Final - WER no Teste: {test_wer:.4f} ({test_wer*100:.2f}%)")

    except Exception as e:
        print(f"\n❌ Erro na avaliação: {str(e)}")

# %% [markdown]
# ## Treina o modelo Speech Otimizado da LSTM

# %%
# ========== CONFIGURAÇÕES ========== #
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")
BATCH_SIZE = 16
EPOCHS = 50
LEARNING_RATE = 0.001

DATA_DIR = "/content/projeto_redes_neurais/data/raw"
PROCESSED_DIR = "/content/projeto_redes_neurais/data/processed"
MODEL_DIR = "/content/drive/MyDrive/RN/modelos"
DATASET_DIR = "/content/projeto_redes_neurais/datasets"
MODEL_PATH = os.path.join(MODEL_DIR, "best_model_OptimizedSpeechLSTM.pth")

# ========== FUNÇÕES DE TREINAMENTO ========== #
def train(model, train_loader, val_loader, criterion, optimizer, vocab):
    best_loss = float('inf')

    for epoch in range(EPOCHS):
        model.train()
        total_loss = 0

        for inputs, targets, target_lengths in train_loader:
            inputs = inputs.to(DEVICE)
            targets = targets.to(DEVICE)
            target_lengths = target_lengths.to(DEVICE)

            optimizer.zero_grad()
            outputs = model(inputs)

            input_lengths = torch.full(
                size=(inputs.size(0),),
                fill_value=outputs.size(1),
                dtype=torch.long,
                device=DEVICE
            )

            log_probs = outputs.permute(1, 0, 2)
            loss = criterion(log_probs, targets, input_lengths, target_lengths)
            loss.backward()
            optimizer.step()
            total_loss += loss.item()

        val_loss = evaluate(model, val_loader, criterion)

        # Salva o melhor modelo
        if val_loss < best_loss:
            best_loss = val_loss
            torch.save({
                'model_state_dict': model.state_dict(),
                'vocab': vocab
            }, MODEL_PATH)
            print(f"✅ Novo melhor modelo salvo em epoch {epoch+1}")

        print(f"Epoch {epoch+1}/{EPOCHS} | Train Loss: {total_loss/len(train_loader):.4f} | Val Loss: {val_loss:.4f}")

# ========== FUNÇÃO DE AVALIAÇÃO (VALIDAÇÃO) ========== #
def evaluate(model, val_loader, criterion):
    model.eval()
    total_loss = 0
    with torch.no_grad():
        for inputs, targets, target_lengths in val_loader:
            inputs = inputs.to(DEVICE)
            targets = targets.to(DEVICE)
            target_lengths = target_lengths.to(DEVICE)

            outputs = model(inputs)
            input_lengths = torch.full(
                size=(inputs.size(0),),
                fill_value=outputs.size(1),
                dtype=torch.long,
                device=DEVICE
            )

            log_probs = outputs.permute(1, 0, 2)
            loss = criterion(log_probs, targets, input_lengths, target_lengths)
            total_loss += loss.item()

    return total_loss / len(val_loader)

# ========== EXECUÇÃO DO TREINAMENTO ========== #
def main():
    from torch.utils.data import Dataset

    # Carregar dados processados
    processed_data = torch.load(
        os.path.join(PROCESSED_DIR, "librispeech_processed.pt"),
        map_location='cpu'
    )

    # Criar dataset temporário
    class TempDataset(Dataset):
        def __init__(self, data):
            self.waveforms = data['waveforms']
            self.transcripts = data['transcripts']
            self.vocab = data['vocab']

        def __len__(self):
            return len(self.waveforms)

        def __getitem__(self, idx):
            waveform = self.waveforms[idx]
            if waveform.dim() == 2:
                waveform = waveform.unsqueeze(0)
            return waveform, self.transcripts[idx]

    full_dataset = TempDataset(processed_data)

    # Dividir dataset
    train_size = int(0.7 * len(full_dataset))
    val_size = int(0.15 * len(full_dataset))
    test_size = len(full_dataset) - train_size - val_size
    train_set, val_set, _ = random_split(
        full_dataset,
        [train_size, val_size, test_size],
        generator=torch.Generator().manual_seed(42)
    )

    train_loader = DataLoader(train_set, batch_size=BATCH_SIZE, collate_fn=collate_fn, shuffle=True)
    val_loader = DataLoader(val_set, batch_size=BATCH_SIZE, collate_fn=collate_fn)

    # Carregar modelo
    model = OptimizedSpeechLSTM(num_classes=len(full_dataset.vocab)).to(DEVICE)
    criterion = nn.CTCLoss(blank=full_dataset.vocab['<blank>']).to(DEVICE)
    optimizer = optim.Adam(model.parameters(), lr=LEARNING_RATE)

    # Iniciar treinamento
    train(model, train_loader, val_loader, criterion, optimizer, full_dataset.vocab)

if __name__ == "__main__":
    os.environ['TORCHDYNAMO_DISABLE'] = '1'
    main()

# %% [markdown]
# ## Avalia o modelo de acordo com a métrica WER no conjunto de testes

# %%
# ========== CONFIGURAÇÕES ========== #
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")
BATCH_SIZE = 16
MODEL_PATH = os.path.join("/content/drive/MyDrive/RN/modelos", "best_model_OptimizedSpeechLSTM.pth")
PROCESSED_DIR = "/content/projeto_redes_neurais/data/processed"
DATASET_DIR = "/content/projeto_redes_neurais/datasets"

# ========== FUNÇÕES DE DECODIFICAÇÃO ========== #
def decode_predictions(ctc_output, vocab, blank_index=0):
    _, max_indices = torch.max(ctc_output, dim=2)
    decoded_texts = []
    for batch in max_indices:
        current_text = []
        prev_char = -1
        for char_idx in batch:
            char_idx = char_idx.item()
            if char_idx != prev_char and char_idx != blank_index:
                if char_idx in vocab.values():
                    current_text.append(char_idx)
            prev_char = char_idx
        idx_to_char = {v: k for k, v in vocab.items()}
        decoded = ''.join([idx_to_char.get(idx, '') for idx in current_text])
        decoded_texts.append(decoded)
    return decoded_texts

# ========== CÁLCULO DO WER ========== #
def calculate_test_wer(model, test_set, vocab):
    test_loader = DataLoader(test_set, batch_size=BATCH_SIZE, collate_fn=collate_fn)
    total_wer = 0
    total_samples = 0
    with torch.no_grad():
        for batch_idx, (inputs, targets, target_lengths) in enumerate(test_loader):
            inputs = inputs.to(DEVICE)
            outputs = model(inputs)
            predictions = decode_predictions(outputs, vocab)
            idx_to_char = {v: k for k, v in vocab.items()}
            references = [''.join(idx_to_char[idx.item()] for idx in target if idx.item() in idx_to_char and idx_to_char[idx.item()] != '<blank>') for target in targets]
            batch_wer = wer(references, predictions)
            total_wer += batch_wer * len(references)
            total_samples += len(references)
    return total_wer / total_samples if total_samples > 0 else float('inf')

# ========== EXECUÇÃO DA AVALIAÇÃO ========== #
def evaluate_model():
    # Carregar modelo treinado
    checkpoint = torch.load(MODEL_PATH, map_location=DEVICE)
    vocab = checkpoint['vocab']

    model = OptimizedSpeechLSTM(num_classes=len(vocab)).to(DEVICE)
    model.load_state_dict(checkpoint['model_state_dict'])
    model.eval()

    # Carregar conjunto de testes
    processed_data = torch.load(os.path.join(PROCESSED_DIR, "librispeech_processed.pt"), map_location='cpu')
    test_set = Subset(processed_data, range(int(0.85 * len(processed_data)), len(processed_data)))

    # Calcular WER
    test_wer = calculate_test_wer(model, test_set, vocab)
    print(f"\n✅ Resultado Final - WER no Teste: {test_wer:.4f} ({test_wer*100:.2f}%)")

if __name__ == "__main__":
    evaluate_model()

# %% [markdown]
# ## Treinamento do modelo Híbrido da LSTM

# %%
# ========== CONFIGURAÇÕES ========== #
BATCH_SIZE = 16
EPOCHS = 50
LEARNING_RATE = 0.001

DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")

DATA_DIR = "/content/projeto_redes_neurais/data/raw"
PROCESSED_DIR = "/content/projeto_redes_neurais/data/processed"
MODEL_DIR = "/content/drive/MyDrive/RN/modelos"
DATASET_DIR = "/content/drive/MyDrive/RN/datasets"

# ========== FUNÇÃO DE TREINO ========== #
def train(model, train_loader, val_loader, criterion, optimizer, vocab):
    best_loss = float('inf')  # Inicializa com um valor alto
    best_model_path = os.path.join(MODEL_DIR, "best_model.pth")

    for epoch in range(EPOCHS):
        model.train()
        total_loss = 0
        for inputs, targets, target_lengths in train_loader:
            inputs = inputs.to(DEVICE)
            targets = targets.to(DEVICE)
            target_lengths = target_lengths.to(DEVICE)

            optimizer.zero_grad()
            outputs = model(inputs)

            # Preparar os comprimentos das entradas para o CTCLoss
            input_lengths = torch.full(
                size=(inputs.size(0),),
                fill_value=outputs.size(1),
                dtype=torch.long,
                device=DEVICE
            )

            log_probs = outputs.permute(1, 0, 2)  # (T, N, C)
            loss = criterion(log_probs, targets, input_lengths, target_lengths)
            loss.backward()
            optimizer.step()
            total_loss += loss.item()

        # Calcular validação
        val_loss = evaluate(model, val_loader, criterion)

        # Se a perda de validação for menor, salvar o modelo
        if val_loss < best_loss:
            best_loss = val_loss
            torch.save({
                'model_state_dict': model.state_dict(),
                'vocab': vocab
            }, best_model_path)
            print(f"✅ Melhor modelo atualizado! Salvo em {best_model_path} (Val Loss: {val_loss:.4f})")

        print(f"Epoch {epoch+1}/{EPOCHS} | Train Loss: {total_loss/len(train_loader):.4f} | Val Loss: {val_loss:.4f}")

# ========== EXECUÇÃO PRINCIPAL ========== #
if __name__ == "__main__":
    # Carregar dados processados
    processed_data = torch.load(os.path.join(PROCESSED_DIR, "librispeech_processed.pt"), map_location='cpu')

    # Criar dataset
    class TempDataset(torch.utils.data.Dataset):
        def __init__(self, data):
            self.waveforms = data['waveforms']
            self.transcripts = data['transcripts']
            self.vocab = data['vocab']
        def __len__(self):
            return len(self.waveforms)
        def __getitem__(self, idx):
            return self.waveforms[idx], self.transcripts[idx]

    full_dataset = TempDataset(processed_data)

    # Divisão do dataset
    train_size = int(0.7 * len(full_dataset))
    val_size = int(0.15 * len(full_dataset))
    test_size = len(full_dataset) - train_size - val_size
    train_set, val_set, _ = random_split(full_dataset, [train_size, val_size, test_size],
                                         generator=torch.Generator().manual_seed(42))

    train_loader = DataLoader(train_set, batch_size=BATCH_SIZE, collate_fn=collate_fn, shuffle=True)
    val_loader = DataLoader(val_set, batch_size=BATCH_SIZE, collate_fn=collate_fn)

    # Inicializar modelo e otimizador
    model = HybridCTCLSTM(input_size=128, hidden_size=256, num_layers=2, num_classes=30, dropout=0.3).to(DEVICE)
    criterion = nn.CTCLoss(blank=full_dataset.vocab['<blank>']).to(DEVICE)
    optimizer = optim.Adam(model.parameters(), lr=LEARNING_RATE)

    # Treinar o modelo
    train(model, train_loader, val_loader, criterion, optimizer, full_dataset.vocab)
# Out:
# Epoch 1/50 | Train Loss: 3.9083 | Val Loss: 3.0324
# Epoch 2/50 | Train Loss: 2.9210 | Val Loss: 2.9075
# Epoch 3/50 | Train Loss: 2.8935 | Val Loss: 2.8941
# Epoch 4/50 | Train Loss: 2.8857 | Val Loss: 2.8829
# Epoch 5/50 | Train Loss: 2.8505 | Val Loss: 2.8711
# Epoch 6/50 | Train Loss: 2.7979 | Val Loss: 2.8245
# Epoch 7/50 | Train Loss: 2.6352 | Val Loss: 7.7569
# Epoch 8/50 | Train Loss: 2.4335 | Val Loss: 3.9022
# Epoch 9/50 | Train Loss: 2.3015 | Val Loss: 2.3099
# Epoch 10/50 | Train Loss: 2.1820 | Val Loss: 2.3470
# Epoch 11/50 | Train Loss: 2.0778 | Val Loss: 2.8189
# Epoch 12/50 | Train Loss: 1.9844 | Val Loss: 2.0505
# Epoch 13/50 | Train Loss: 1.9057 | Val Loss: 2.2662
# Epoch 14/50 | Train Loss: 1.8188 | Val Loss: 22.7326
# Epoch 15/50 | Train Loss: 1.7450 | Val Loss: 2.9046
# Epoch 16/50 | Train Loss: 1.6783 | Val Loss: 2.0295
# Epoch 17/50 | Train Loss: 1.6053 | Val Loss: 2.6273
# Epoch 18/50 | Train Loss: 1.5446 | Val Loss: 1.8624
# Epoch 19/50 | Train Loss: 1.4888 | Val Loss: 1.7167
# Epoch 20/50 | Train Loss: 1.5076 | Val Loss: 1.8996
# Epoch 21/50 | Train Loss: 1.6512 | Val Loss: 2.8192
# Epoch 22/50 | Train Loss: 1.5536 | Val Loss: 1.6727
# Epoch 23/50 | Train Loss: 1.4064 | Val Loss: 1.7478
# Epoch 24/50 | Train Loss: 1.3241 | Val Loss: 9.4042
# Epoch 25/50 | Train Loss: 1.2672 | Val Loss: 5.9160
# Epoch 26/50 | Train Loss: 1.2183 | Val Loss: 1.5877
# Epoch 27/50 | Train Loss: 1.1780 | Val Loss: 1.8498
# Epoch 28/50 | Train Loss: 1.1353 | Val Loss: 1.5487
# Epoch 29/50 | Train Loss: 1.0937 | Val Loss: 2.0866
# Epoch 30/50 | Train Loss: 1.0494 | Val Loss: 2.0502
# Epoch 31/50 | Train Loss: 1.0107 | Val Loss: 3.0785
# Epoch 32/50 | Train Loss: 0.9691 | Val Loss: 1.9384
# Epoch 33/50 | Train Loss: 0.9349 | Val Loss: 2.1783
# Epoch 34/50 | Train Loss: 0.9121 | Val Loss: 3.7290
# Epoch 35/50 | Train Loss: 0.8642 | Val Loss: 1.6802
# Epoch 36/50 | Train Loss: 0.8378 | Val Loss: 2.7691
# Epoch 37/50 | Train Loss: 0.8044 | Val Loss: 6.6267
# Epoch 38/50 | Train Loss: 0.7782 | Val Loss: 1.7032
# Epoch 39/50 | Train Loss: 0.7380 | Val Loss: 3.2438
# Epoch 40/50 | Train Loss: 0.7196 | Val Loss: 2.2988
# Epoch 41/50 | Train Loss: 0.6941 | Val Loss: 4.0219
# Epoch 42/50 | Train Loss: 0.6665 | Val Loss: 1.6076
# Epoch 43/50 | Train Loss: 0.6402 | Val Loss: 4.4538
# Epoch 44/50 | Train Loss: 0.6131 | Val Loss: 2.0143
# Epoch 45/50 | Train Loss: 0.5896 | Val Loss: 1.6923
# Epoch 46/50 | Train Loss: 0.5770 | Val Loss: 1.7465
# Epoch 47/50 | Train Loss: 0.5449 | Val Loss: 1.8550
# Epoch 48/50 | Train Loss: 0.5296 | Val Loss: 1.5964
# Epoch 49/50 | Train Loss: 0.5122 | Val Loss: 3.4727
# Epoch 50/50 | Train Loss: 0.4897 | Val Loss: 3.7932
# Real: we might provisionally though perhaps not quite correctly define memory as that way of knowing about the past which has no analogue in our knowledge of the future such a definition would at least serve to mark the problem with which we are concerned though some expectations may deserve to rank with memory as regards immediacy  |  Previsto: forlit forfigoenali forfthe haf fou fith foe lefl fhrfa filey  fa feotly of eleye if of fhe hah fhor fhoafeol heal lafh a allalife te fefer fufter effedithee oit it l sod for houth for faotie i the fhire fleifhor fe fo sothih fi fifoh hitofie to foile fo fiee ha to flaf fiflifif
# Real: those pretty wrongs that liberty commits when i am sometime absent from thy heart thy beauty and thy years full well befits for still temptation follows where thou art  |  Previsto: foh rit yethohh fhi fihirtih he hifoie fonome ati fovi hafi friutrlyf avi  fole fili fif faiffo fio fih fetio fovoh fli hahuh
# Real: what is called perception differs from sensation by the fact that the sensational ingredients bring up habitual associates images and expectations of their usual correlates all of which are subjectively indistinguishable from the sensation  |  Previsto: luithi halth fhecsefe fhifire frotfesfafheh fhouthe faf fha the tfifetinot iff fleefhf fhadfifrooh ha fif fifviteihe i if fifteflth toe there fehilh fore  fol iflihe foe ho feiftfifl fitie fefifithe h foififaife
# Real: many of these again and also many of the other aristocracy of less degree have in turn attached to their persons a more or less comprehensive group of vicarious consumer in the persons of their wives and children their servants retainers et cetera  |  Previsto: lonyeo thefefefiole forrheryeorrerte uf fof fiefe vhlet fitly hofhote forth feffe f fi the fhih for far oo o f fofoe had for foh forvi fid hor fivefintfeasther for fverlifefof fefe feiferveihf fhefeitih fafferefes
# Real: she was gone out into the village on some errand when as she was descending the steep street her foot slipped on the ice and she fell it was dark and no one saw her mischance till after a time her groans attracted the attention of a passer by  |  Previsto: who whi dai ol in to theviliha bfur thare i litfaso wis hefetotitsfe stret o fo sfiso ifishe feh fofhat fayoishoffeor mistheaef f sreutort lime hor frooit he hastifetete ottie hessiefie
# Real: it is black in misfortune it is blacker still in crime these two blacknesses amalgamated compose slang  |  Previsto: fitiflaflih fliffiffef felhi fele foae fe foflahf hive fovf f a au eeiifi fothohe fatt
# Real: it was a serious crime indeed mister watson told them and tom gates bade fair to serve a lengthy term in state's prison as a consequence of his rash act  |  Previsto: fo le aseris caiflefis erloto fothe   fatougt fah fa fad fe fertal fe feroh idhi faf fliter hia e cote flih fofhisres af
# Real: three seconds before the arrival of j b hobson's letter i no more dreamed of chasing the unicorn than of trying for the northwest passage  |  Previsto: frafeihi foforethe a ou olot fat hats enfltefino oytad if cacte ot the eveigfoef thath fief ah hifhi fastheh
# Real: then they all marched out a little way into the fields and found that the army of pinkies had already formed and was advancing steadily toward them  |  Previsto: fhoiona a ite seot elereathef fo the ferof hir faie ife oei forher forh oete fotefotol the fatfi fealhe flofe
# Real: to burn without ceasing to fly therein lies the marvel of genius  |  Previsto: fofeotehah fesitefofole fheor
# Real: irene burgoyne one of her family told me in confidence that there was a romance somewhere back in the beginning  |  Previsto: filo verfore otl te fhelih f f forti the hofte fe fort rerhotthe for thr hato the fe
# Real: congratulations were poured in upon the princess everywhere during her journey  |  Previsto: efeagalachr fo fie and hatehe to fetly hefhorhoe
# Real: i did not then realize the importance of the ministry  |  Previsto: fi tiryf fhadeliliielie fohir efemie
# Real: said missus horton a few minutes after  |  Previsto: fiitihefo h froha
# Real: the variability of multiple parts  |  Previsto: feferi ie it hir mot th fo
# Real: we don't know where it will take us  |  Previsto: fheoiulalu fahe
# Real: then the church was disincorporated and its property both real and personal confiscated and escheated to the government of the united states and although the personal property was soon restored real estate of great value long lay in the hands of the court's receiver and the mormon church had to pay the national government high rental on its own property  |  Previsto: ftleifti crch whis hiinfoflifiich fothly hl h liouo ho frsota  fortis feifi ficeoietet to he fivet tefo le heifaif fio falltho the firs ol foufle thi seoes foo fovitey a fla fely il lantlayit i fadti the fourterseefou fothe forvichared a thifadtvetvesthr re ther ir the  filei fo oifoh haofti
# Real: if any still retained rancor against him in his present condition they passed in silence while his well wishers more generous than prudent accompanied his march with tears with acclamations and with prayers for his safety  |  Previsto: fefao etfelylrathiaeif fi fihis fastei fifiie fefofi sifothis leillithrs fhl o ferhe tate fote fhefefii his loh fol  fe fote folifos  fotie foihe foihi sef
# Real: in an image of a well known face for example some parts may feel more familiar than others when this happens we have more belief in the accuracy of the familiar parts than in that of the unfamiliar parts  |  Previsto: finfilihe afhe ollho fa fliefhafaff so floth fla fle frorefermleere he oi foti tlato flehah fheorfiuly fo the afii cleetfof the fheitor fhotie fretehath fo the fe foeite ho
# Real: the christmas holidays came and she and anne returned to the parsonage and to that happy home circle in which alone their natures expanded amongst all other people they shrivelled up more or less  |  Previsto: tewhisiuhol ius flaf fhan sha airtere to the fustiisfentthat ha hy hoi serfohf forhelih folvaolievernaterh efei fono falligh if frfourevish hihur tout horlef
# Real: one of mister hopkins's first tasks after calling his faithful henchmen around him was to make a careful canvass of the voters of his district to see what was still to be accomplished  |  Previsto: fortefhisterhefe tostast ofthar falliy his flat for hith feeloe  fustor ata carfta aroheh foaf thefothers of his histrei to see ot tis hil tifheh houfli
# Real: beth was a beautiful girl the handsomest of the three cousins by far yet eliza surpassed her in natural charm and seemed well aware of the fact  |  Previsto: fahfis af feit fo ge h farhed wo istfef thefryfesthes fa faehh fefulise af farfast frt ha vet trel thote fi hi te lillelatf the fe
# Real: but the bear instead of obeying maintained the seat it had taken and growled  |  Previsto: fo thefa as thiote fa  fafaithe fifitve fefe thflo
# Real: indeed he had looked away with the purpose of not seeing it  |  Previsto: fimnsie he hee ha ot tovear ye wat taf harthis hov hotfle
# Real: i'll do anything you wish me to bartley she said tremulously  |  Previsto: fofifanefhiilish re tefothe she si oals fe
# Real: the waves rise above our heads  |  Previsto: folah flise fof i e hea
# Real: then now let me explain to you the order of our entertainment first timaeus who is a natural philosopher will speak of the origin of the world going down to the creation of man and then i shall receive the men whom he has created and some of whom will have been educated by you and introduce them to you as the lost athenian citizens of whom the egyptian record spoke  |  Previsto: foovel fofelf foefeor tir ufiihfet fi faff fofoleth ifolotiih foh fhe fofetorito oe fleflelh foefeaih hilitfoeilefoefishoe fefeve fo the hafre foi fole foufhl hihe fateflefiaefoadehfo fiefoi a fo hoft the forefiiifoufoico eafi fo
# Real: a reconciliation between the two conflicting requirements is effected by a resort to make believe many and intricate polite observances and social duties of a ceremonial nature are developed many organizations are founded with some specious object of amelioration embodied in their official style and title there is much coming and going and a deal of talk to the end that the talkers may not have occasion to reflect on what is the effectual economic value of their traffic  |  Previsto: filyfiufie fofre hietfr ufefreliefieh fiftifef frefiley soe flifityfffmeeefrofrlitof sertie fi fo sustio flefofovf ferellele fr i ef tal e frear fen ivatiof for fouhedhf tif foe fithwas foffevfoven heleltfm en fotitfer her of fif for foteih fifolhf thesset lihd coemelel f fond af te of fof fretaolnit fhr fofefle ho foathafetio flihfeftrfou her tefle fih foth fr mit ie falle of fhfafi
# Real: he had a good appetite could tell a good story without laughing was celebrated for his witty repartees and his sociable manners but he spent his life at home seldom going out and seeing hardly anyone because he always had a pipe in his mouth and was surrounded by at least twenty cats with which he would amuse himself all day  |  Previsto: feadd for ethe fa fetfelly th fory iyt aulee fhe fet iv y ifit he flea ifah fotoefoemetif foi fetiflth ha folthe horof fev fithe eaefe heserleit i a fiafithfhefye fo eadefil fete fafffohiy foout ae th fha fhofe
# Real: in determining whether two or more allied forms ought to be ranked as species or varieties naturalists are practically guided by the following considerations namely the amount of difference between them and whether such differences relate to few or many points of structure and whether they are of physiological importance but more especially whether they are constant  |  Previsto: ecraly hethf tol iflir a ih fo ho hevlih hi fe fee foforietdefafale frfit foihi if fithe filigfeehflal fe thoit hivhfi forthrimtta fha wether seft heftirhe ulie fe ovayfoh hrogthr fe i av aarfif el ue fou for h h  fother fescthalye feittir thay o fhogth
# Real: they were later used as reserve machines and finally with the engine retired from service as part of the collection of edisonia but they remain in practically as good condition as when installed in eighteen eighty three  |  Previsto: fheoorlinis yois the feie the herovthe sherfeisea fili fothithite fhoe fhitie fhon frithe host torthe theeh fofilho hit the fret fofthir lelahf fenthe tfiflise flifiditi  fhasloiflaithe feh
# Real: the standard edison meter practice was to remove the cells once a month to the meter room of the central station company for examination another set being substituted  |  Previsto: thi stentei at i sis lie her frat fihie fhlosd to tie lete the fhele fle for honh fo the liehirlithe hir the feathi fithon fofor he fial sonihe fenotisheo fleihe softrite
# Real: he himself recited the same passage in french and politely pointed out the parts in which he thought that i had improved on the original  |  Previsto: frorofofey fite the fa efifeifafofolyiffi eohto fithelih tefofhei hatho erothereleiti
# Real: but here he was at a terrible disadvantage as compared with the owls hawks and eagles he had no rending claws  |  Previsto: fuo feewt lih hat ifhf fardivlefitiffiid i hase fufeed toe fe h of h folf ha fheglh fehia ynoveintin e fah
# Real: oh let him come along she urged i do love to see him about that old house  |  Previsto: fol leitiv halhase tecfloteitthatuhu
# Real: the young girls had indeed made themselves small indeed invisible  |  Previsto: ftleangul hai in fe laithi o flah fintfeta theo
# Real: it was on the last day of january that the repairs of the schooner were completed  |  Previsto: filas on helass t a fanilite fhat forfarstot the cottirhe heflite
# Real: oh that made him so angry  |  Previsto: o eaeis silaly
# Real: come come i am getting really tired of your absence  |  Previsto: foo come ivanivlaly heate atf
# Real: that's what you'd like to be doing is it  |  Previsto: feact wir huflih fefilliehiseh
# Real: but there seemed no reason to fear  |  Previsto: ftotife noles on ae fi
# Real: and so the story of mormonism runs on its finale has not yet been written the current press presents continuously new stages of its progress new developments of its plan  |  Previsto: fho shol te soy fovit is foal fit foelly has hahiv the titfe fi fes fisee o fiisly   fi sthiythis ofh ite froflesef foitthev oithie o itfo
# Real: the dialogue is primarily concerned with the animal creation including under this term the heavenly bodies and with man only as one among the animals  |  Previsto: fofo o thofierty fl fet fo the faile fofote over t ifio fo feav oef oefofreef foe a fo voite ivotetef eee
# Real: the tree only came to himself when he was unloaded in a court yard with the other trees and heard a man say that one is splendid we don't want the others  |  Previsto: fhefeealle ca fo sof fhe helse foftheloteit he horrl thr ar fo fhe fotheflhs e fo te matsa falihese rofhi flieo fhoht fher ufis
# Real: sometimes i don't want to do anything at all and sometimes i want to pull the four corners of the divide together he threw out his arm and brought it back with a jerk so like a table cloth  |  Previsto: fofie i lfohtit il la tfi al a faid foe fime wotha fote for fourhis of fte ief ie toe get  foefir ofti fa a throuhiffafo the fher  fa fihie aivbe fl
# Real: the ideas also remain but they have become types in nature forms of men animals birds fishes  |  Previsto: ea foe folte fohele  fothe hat he fofiofeveh foh fore hafle  faieh h fe  feie
# Real: mainhall vouched for her constancy with a loftiness that made alexander smile even while a kind of rapid excitement was tingling through him  |  Previsto: fohu houtfh fo thr fouhfthe foe the the loffter tit forfhe olie tov te frioefotetlot hoitefatite fitoehthe folet foe
# Real: then turning to jane she asked in a somewhat altered tone has she been a good girl jane  |  Previsto: the frofife sheha fimo oftofoltir fha fiste fot he fhe fro feif
# Real: spoke the squire losing all patience and it was to you that i gave another purse in consolation  |  Previsto: fofhi foitof isfeivalfatio fit i wis sa fed fhat ha feve on hat or ferson oucali shan
# Real: a sudden impulse came over him to enter and see if they were indeed the proofs  |  Previsto: fose in foulf faivlfr hate aner fasefeeit
# Real: but in such a case miss milner's election of a husband shall not direct mine  |  Previsto: foifati fahf toefrelolir ole fer ote haifot fatle heleth hri
# Real: dorcas in her strange way was moved  |  Previsto: fofofrestragela fiy
# Real: the rector did not ask for a catechism to hear the lesson from  |  Previsto: foeletiu fhe fo haf forth fhetvifio tefeirtileat ho
# Real: the man entered and took the papers sheet by sheet from the central table  |  Previsto: fo a eaterh anto fo faii sheficio for his afo ath
# Real: mohammed also speaks highly of christ  |  Previsto: fhohonals fhefowtir fhose
# Real: and what through the left hand window  |  Previsto: and hit frithe lefamn ly tdohe
# Real: the former boolooroo groaned  |  Previsto: tofotouthelelefo
# Real: he doesn't say exactly what it is said ruth a little dubiously but it's something about land and railroads and thee knows father that fortunes are made nobody knows exactly how in a new country  |  Previsto: uf fay faflyflitihehf ffeflt favitefififleffofi softy af out feavd a viltrle at fevois fatirh fofoutiorit i aleverveaeteffatly ho fifvitte feaher
# Real: she tried this morning an air or two upon the piano sang a simple song in a sweet but slightly metallic voice and then seating herself by the open window read philip's letter  |  Previsto: ferie th foti a fairo fe o o fote fhatafa if for fho hoate fut ihfle fi fithly h holliefolh fenflah feefhor fof fihe fof to thehe flat foi fue
# Real: he could write in one style but not in another and the greek language had not as yet been fashioned by any poet or philosopher to describe physical phenomena  |  Previsto: feeflrifo out fil fa tho fifl ote fovefreflaleh fa hlot hifeaflt faa fa fae folitt ho fholotii fefie fithe folefhel outere
# Real: he made a bow so deep that his back came near breaking and he was dumbfounded i can tell you when he saw it was nobody but anders  |  Previsto: featha tha fof fhefethi fa fa helethe ans he was doefoatefithanfeiu fous he sat itlih he heldhothe h fa
# Real: if ever he was impelled to cast sin from him and to repent the impulse that moved him was the wish to be her knight  |  Previsto: fiefittle fiwi thir fhelle to fha fi fothi han tar te feah  fiithoh for flithi huh fiflifithi fhore he
# Real: mother carey poured coffee nancy chocolate and the others helped serve the sandwiches and cake doughnuts and tarts  |  Previsto: frotefeay forh faftet fate faofif fiiothe fofot thefalif fe fa fafo
# Real: he passed through henley saint albans and came so near to london as harrow on the hill  |  Previsto: thehoue fofhinifefalte fefasore iselote h as hohothe hi
# Real: won't you run into the house and see if martha can't spare one or two more maids  |  Previsto: folt ovetigh of house a feofflitha ci failet ic toirlorle
# Real: anyhow we'll leave instructions to ship the whole menagerie to france  |  Previsto: fa hat iley ve'xtrersth is shis shif h a inaserli he fleah
# Real: again he searched his own thoughts nor ineffectually as before  |  Previsto: figan i fet ftorfoe hoh floir iti fahe fohe fe
# Real: angor pain painful to hear  |  Previsto: ainedah  fa  fainfo tor he
# Real: alexander rose and shook himself angrily yes i know i'm cowardly  |  Previsto: foit afhirfhowise if shertutsoffi orly festi do in horlyh
# Real: i shouldn't wonder if she could laugh about it with me now  |  Previsto: fototthe for toteh fhe for tlator otithelerlorr
# Real: if spoken to she would not speak again  |  Previsto: fhefofiteshe arhatetefe
# Real: said lord chelford addressing me  |  Previsto: fovo chaforith fe ref
# Real: o love o troth  |  Previsto: foe to fo
# Real: he selected a small gold bottle with a pepper box top so that the powder might be sprinkled on any object through the small holes  |  Previsto: feflih fof the fale lote frotie fo the hafviueh ou ha fo thit tha heawtie ih tifliyd hiv iheae oeftfi the ahi
# Real: this truth which i have learned from her lips is confirmed by his face in which we have both beheld that of our son  |  Previsto: iofofeitle fo foeofofoeoofoe
# Real: dear me ejaculated the old gentleman in the utmost amazement and such a time as i've had to get her here too  |  Previsto: feafe fafeflly he fey ole fefhe fole oflflfan fofftofimif i hathe hetv iter
# Real: come to me men here here he raised his voice still louder  |  Previsto: clotrnye medh feat fe filase this folse tiolh outhi
# Real: these means cannot be contaminated  |  Previsto: fi is hmmiat haofey frhii
# Real: robin fitzooth  |  Previsto: fofofite
# Real: you are positive then  |  Previsto: foufosit fha
# Real: hans stirs not  |  Previsto: fos firrs ha
#
# ✅ Resultado Final - WER no Teste: 0.9815 (98.15%)

# %% [markdown]
# ## Avalia o modelo de acordo com a métrica WER no conjunto de testes

# %%
# ========== CONFIGURAÇÕES ========== #
BATCH_SIZE = 16
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")

DATASET_DIR = "/content/drive/MyDrive/RN/datasets"
MODEL_DIR = "/content/drive/MyDrive/RN/modelos"
MODEL_PATH = os.path.join(MODEL_DIR, "best_model.pth")

# ========== FUNÇÃO PARA AVALIAÇÃO ========= #
def calculate_test_wer(model, test_loader, vocab):
    total_wer = 0
    total_samples = 0
    with torch.no_grad():
        for batch_idx, (inputs, targets, target_lengths) in enumerate(test_loader):
            inputs = inputs.to(DEVICE)
            outputs = model(inputs)
            predictions = decode_predictions(outputs, vocab)
            idx_to_char = {v: k for k, v in vocab.items()}
            references = []
            valid_indices = []
            for i, target in enumerate(targets):
                try:
                    text = ''.join([idx_to_char[idx.item()]
                                    for idx in target
                                    if idx.item() in idx_to_char and idx_to_char[idx.item()] != '<blank>'])
                    if not text.strip():
                        raise ValueError("Texto vazio")
                    references.append(text)
                    valid_indices.append(i)
                except Exception as e:
                    print(f"Batch {batch_idx}, Amostra {i} ignorada: {str(e)}")
                    continue
            valid_predictions = [predictions[i] for i in valid_indices]
            for ref, pred in zip(references, valid_predictions):
                print(f"Real: {ref}  |  Previsto: {pred}")
            if len(references) > 0:
                batch_wer = wer(references, valid_predictions)
                total_wer += batch_wer * len(references)
                total_samples += len(references)
    return total_wer / total_samples if total_samples > 0 else float('inf')

# ========== EXECUÇÃO PRINCIPAL ========== #
if __name__ == "__main__":
    # Carregar dataset de teste
    test_set = torch.load(os.path.join(DATASET_DIR, "test_set.pt"), map_location='cpu')

    test_loader = DataLoader(test_set, batch_size=BATCH_SIZE, collate_fn=collate_fn)

    # Carregar modelo treinado
    checkpoint = torch.load(MODEL_PATH, map_location=DEVICE)
    model = HybridCTCLSTM(input_size=128, hidden_size=256, num_layers=2, num_classes=30, dropout=0.3).to(DEVICE)
    model.load_state_dict(checkpoint['model_state_dict'])
    vocab = checkpoint['vocab']

    # Avaliar o modelo
    test_wer = calculate_test_wer(model, test_loader, vocab)
    print(f"\n✅ Resultado Final - WER no Teste: {test_wer:.4f} ({test_wer*100:.2f}%)")
